# %%
pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (2.9.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.23.2)
# Requirement already satisfied: six>=1.5 in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (0.11.2)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (3.5.3)
# Requirement already satisfied: numpy>=1.15 in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.23.2)
# Requirement already satisfied: scipy>=1.0 in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.9.1)
# Requirement already satisfied: pandas>=0.23 in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (4.37.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.23->seaborn) (2022.2.1)
# Requirement already satisfied: six>=1.5 in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (3.5.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.37.1)
# Requirement already satisfied: six>=1.5 in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (1.23.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import psycopg2
import pandas as pd
import psycopg2.extras
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
class PostgresConnection(object):
    def __init__(self):
        self.connection = psycopg2.connect(database="prescription_data_db",
                                           user = "postgres",
                                           password = "mudabbir",
                                           host = "127.0.0.1",
                                           port = "5432")

    def getConnection(self):
        print("Connection to DB established!")
        return self.connection
    
    
con = PostgresConnection().getConnection()
# Out:
# Connection to DB established!

# %% [markdown]
# #

# %% [markdown]
# ### Which drug ingredients or type of appliances are prescribed the most?

# %%
con = PostgresConnection().getConnection()
cur = con.cursor()

insert_stmt = """SELECT chemical_substance_bnf_descr, SUM(TOTAL_QUANTITY) as Total_Quantity
                FROM epd_snow.fact_table as f
                INNER JOIN epd_snow.prescription as p ON p.prescription_key = f.prescription_key
                INNER JOIN epd_snow.bnf_chemical as b ON b.bnf_chemical_substance = p.bnf_chemical_substance
                GROUP BY chemical_substance_bnf_descr
                ORDER BY Total_Quantity desc"""
# psycopg2.extras.execute_batch(cur, insert_stmt, fact_data.values)
cur.execute(insert_stmt)
records = cur.fetchall()
Total_Quantity_df = pd.DataFrame(list(records), columns=['Ingredient / Appliance', 'Total Quantity'])
Total_Quantity_df
# Out:
# Connection to DB established!
#                         Ingredient / Appliance Total Quantity
# 0                            Enteral nutrition     21864044.0
# 1                      Methadone hydrochloride      6407443.0
# 2                                   Emollients      3867251.0
# 3     Other food for special diet preparations      2970488.0
# 4           Alginic acid compound preparations      2499807.0
# ...                                        ...            ...
# 1063        Measles, mumps and rubella vaccine            1.0
# 1064                        Octreotide acetate            1.0
# 1065                           Cervical Collar            1.0
# 1066                               Ster larvae            1.0
# 1067                                Lanreotide            1.0
#
# [1068 rows x 2 columns]

# %%
Total_Quantity_df = Total_Quantity_df.head(20)

# %%
def changetype_to_int(df, col):
    df[col]=df[col].astype('int64')

# %%
changetype_to_int(Total_Quantity_df, 'Total Quantity')
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_4788\1351452570.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col]=df[col].astype('int64')

# %%
Total_Quantity_df.groupby(['Ingredient / Appliance']).sum().plot.pie(subplots = True, title='Most prescribed Ingredient / Appliance', autopct='%1.0f%%')
plt.legend(bbox_to_anchor=(2.5, 1), loc='upper right', title='Ingredient / Appliance')

# %% [markdown]
# ### Which drug ingredients or type of appliances are sold the most?

# %%
con = PostgresConnection().getConnection()
cur = con.cursor()

insert_stmt = """SELECT chemical_substance_bnf_descr, SUM(actual_cost) as Total_Sales
                FROM epd_snow.fact_table as f
                INNER JOIN epd_snow.prescription as p ON p.prescription_key = f.prescription_key
                INNER JOIN epd_snow.bnf_chemical as b ON b.bnf_chemical_substance = p.bnf_chemical_substance
                GROUP BY chemical_substance_bnf_descr
                ORDER BY Total_Sales desc"""
# psycopg2.extras.execute_batch(cur, insert_stmt, fact_data.values)
cur.execute(insert_stmt)
records = cur.fetchall()
Total_Sales_df = pd.DataFrame(list(records), columns=['Ingredient / Appliance', 'Total Sales'])
Total_Sales_df
# Out:
# Connection to DB established!
#           Ingredient / Appliance   Total Sales
# 0                       Apixaban  392459.48363
# 1     Beclometasone dipropionate  310867.54887
# 2              Enteral nutrition  270262.47018
# 3                      Catheters  207576.64680
# 4                    Rivaroxaban  187839.58005
# ...                          ...           ...
# 1063    Paracetamol and caffeine       2.04227
# 1064   Naphazoline hydrochloride       2.00431
# 1065           Absorbent Cottons       1.69827
# 1066                     Alcohol       1.10215
# 1067        Chiropody Appliances       1.04146
#
# [1068 rows x 2 columns]

# %%
Total_Sales_df = Total_Sales_df.head(50)

# %%
def changetype_to_int(df, col):
    df[col]=df[col].astype('float64')

# %%
changetype_to_int(Total_Sales_df, 'Total Sales')
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_4788\4233268188.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col]=df[col].astype('float64')

# %%
plt.figure(figsize = (20, 25))
bar=plt.barh(Total_Sales_df['Ingredient / Appliance'],Total_Sales_df['Total Sales'], height=0.75)
bar[0].set_color('r')
plt.grid(visible=True, color='grey', alpha=0.3, linestyle='-.', linewidth=2)
plt.title('Ingredient / Appliance sold' , fontsize=18)
plt.xlabel('Total Sales', fontsize=18)
plt.ylabel('Ingredient / Appliance', fontsize=20)
plt.show()

# %% [markdown]
# ### Which Primary Care Organization, PCO have made the most sales?

# %%
con = PostgresConnection().getConnection()
cur = con.cursor()

insert_stmt = """SELECT PCO_NAME, SUM(actual_cost) as Total_Sales
                FROM epd_snow.fact_table as f
                INNER JOIN epd_snow.location as l ON l.location_key = f.location_key
                GROUP BY PCO_NAME
                ORDER BY Total_Sales desc"""
# psycopg2.extras.execute_batch(cur, insert_stmt, fact_data.values)
cur.execute(insert_stmt)
records = cur.fetchall()
pco_Total_Sales_df = pd.DataFrame(list(records), columns=['PCO', 'Total Sales'])
pco_Total_Sales_df
# Out:
# Connection to DB established!
#                                          PCO   Total Sales
# 0                     NORTH LINCOLNSHIRE CCG  834348.40812
# 1                           VALE OF YORK CCG  563073.88894
# 2                NORTH EAST LINCOLNSHIRE CCG  478189.96509
# 3                 BASILDON AND BRENTWOOD CCG  463932.67458
# 4                                   BURY CCG  390403.14528
# ..                                       ...           ...
# 296  WARRINGTON & HALTON TEACHING HOSP NHSFT       2.22085
# 297                     THE SOLENT NHS TRUST       1.66257
# 298                         LINCOLNSHIRE STP       1.17729
# 299               ONE ASHFORD HEALTHCARE LTD       0.85405
# 300                                FRAMEWORK       0.20567
#
# [301 rows x 2 columns]

# %%
changetype_to_int(pco_Total_Sales_df, 'Total Sales')

# %%
pco_Total_Sales_df = pco_Total_Sales_df.head(20)

# %%
plt.figure(figsize = (12, 8))
plt.title('PCO Wise Sales')
plt.xlabel('Sales', fontsize=10)
plt.ylabel('Area', fontsize=10)
x=pco_Total_Sales_df['Total Sales']
y=pco_Total_Sales_df['PCO']
plt.grid(visible=True, color='grey', alpha=0.3, linestyle='-.', linewidth=2)
plt.plot(x, y, color = 'g', linestyle = 'solid', marker = 'o', label = "Sales")
plt.legend()
plt.show()

# %% [markdown]
# ### Monthly average sales of 2020, 2021, 2022 combined

# %%
con = PostgresConnection().getConnection()
cur = con.cursor()

insert_stmt = """SELECT month, AVG(actual_cost) as Total_Sales
                FROM epd_snow.fact_table as f
                INNER JOIN epd_snow.time as t ON t.time_key = f.time_key
                GROUP BY month
                ORDER BY Month """
# psycopg2.extras.execute_batch(cur, insert_stmt, fact_data.values)
cur.execute(insert_stmt)
records = cur.fetchall()
Monthly_Total_Sales_df = pd.DataFrame(list(records), columns=['Month', 'Total Sales'])
Monthly_Total_Sales_df
# Out:
# Connection to DB established!
#     Month          Total Sales
# 0       1  40.7127937895684353
# 1       2  39.9429641406210932
# 2       3  47.2870105635845377
# 3       4  42.5769935945000000
# 4       5  42.6937736065000000
# 5       6  41.5719987334366718
# 6       7  44.5026372687268727
# 7       8  43.9631760166016602
# 8       9  43.4486698449844984
# 9      10  44.9886183038303830
# 10     11  46.8930068426842684
# 11     12  44.0788246952347617

# %%
def changetype_to_int(df, col):
    df[col]=df[col].astype('int64')

# %%
changetype_to_int(Monthly_Total_Sales_df, 'Total Sales')

# %%
sizes = Monthly_Total_Sales_df['Total Sales']

# Setting labels for items in Chart
labels =['January', 'February', 'March', 'April', 'May', 'June', 'July', 
         'August', 'September', 'October', 'November', 'December'] 

# colors
colors = ['#FF0000', '#0000FF', '#FFFF00', '#ADFF2F',
		'#FFA500']

# explosion
explode = (0.05, 0.05, 0.05, 0.05, 0.05)

# Pie Chart
plt.pie(sizes, labels=labels,
		autopct='%1.1f%%', pctdistance=0.85)

# draw circle
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()

# Adding Circle in Pie chart
fig.gca().add_artist(centre_circle)

# Adding Title of chart
plt.title('Monthly average sales of 2020, 2021, 2022 combined')

# Add Legends
plt.legend(labels, bbox_to_anchor=(1.5, 1), loc="upper right", title="Months")

# Displaying Chart
plt.show()

# %% [markdown]
# ### Yearly sales

# %%
con = PostgresConnection().getConnection()
cur = con.cursor()

insert_stmt = """SELECT t.year,t.month, SUM(f.actual_cost) as Total_Sales
                FROM epd_snow.fact_table as f
                INNER JOIN epd_snow.time as t ON t.time_key = f.time_key
                GROUP BY t.year,t.month
                ORDER BY Year """
# psycopg2.extras.execute_batch(cur, insert_stmt, fact_data.values)
cur.execute(insert_stmt)
records = cur.fetchall()
YearMonth_Total_Sales_df = pd.DataFrame(list(records), columns=['Year','Month', 'Total Sales'])
YearMonth_Total_Sales_df
# Out:
# Connection to DB established!
#     Year  Month   Total Sales
# 0   2020     11  482433.71740
# 1   2020     12  457361.87619
# 2   2021      1  402608.29891
# 3   2021      2  397008.56258
# 4   2021      3  521415.52509
# 5   2021      4  421985.94144
# 6   2021      5  424708.87082
# 7   2021      6  429192.86299
# 8   2021      7  444080.43125
# 9   2021      8  439587.79699
# 10  2021      9  434443.24978
# 11  2021     10  449841.19442
# 12  2021     11  455332.63344
# 13  2021     12  424170.53889
# 14  2022      1  411525.43850
# 15  2022      2  401730.89134
# 16  2022      3  424182.82515
# 17  2022      4  429553.93045
# 18  2022      5  429166.60131
# 19  2022      6  402205.53968
# 20  2022      7  445883.30885

# %%
changetype_to_int(YearMonth_Total_Sales_df, 'Total Sales')

# %%
a_dims = (15, 12)
fig, ax = plt.subplots(figsize=a_dims)
#sns.set(font_scale = 1)
plt.title('Yearly sales',fontsize=20)
plt.xlabel('Year',fontsize=20)
plt.ylabel('Sales',fontsize=20)

#sns.set_style("darkgrid")
#sns.axes_style("white")
sns.barplot(data=YearMonth_Total_Sales_df,x='Year',y='Total Sales',hue='Month',ax=ax,palette='seismic')
# Out:
# <AxesSubplot:title={'center':'Yearly sales'}, xlabel='Year', ylabel='Total Sales'>

# %% [markdown]
# ### Service centre sales

# %%
con = PostgresConnection().getConnection()
cur = con.cursor()

insert_stmt = """SELECT s.practice_name, SUM(f.actual_cost) as Total_Sales
                FROM epd_snow.fact_table as f
                INNER JOIN epd_snow.service as s ON s.practice_code = f.practice_code
                GROUP BY s.practice_name
                ORDER BY Total_Sales desc"""
# psycopg2.extras.execute_batch(cur, insert_stmt, fact_data.values)
cur.execute(insert_stmt)
records = cur.fetchall()
Service_Total_Sales_df = pd.DataFrame(list(records), columns=['Service', 'Total Sales'])
Service_Total_Sales_df
# Out:
# Connection to DB established!
#                                    Service   Total Sales
# 0                     HAXBY GROUP PRACTICE  344985.68757
# 1                     UNIDENTIFIED DOCTORS  209758.33134
# 2                  ANCORA MEDICAL PRACTICE  159862.29859
# 3                DINNINGTON GROUP PRACTICE  133948.81607
# 4          CAMBRIDGE AVENUE MEDICAL CENTRE  132513.18949
# ...                                    ...           ...
# 1389                SRC COMMUNITY SERVICES        0.5708
# 1390            DONCASTER CLOZAPINE CLINIC       0.30773
# 1391  PORTSMOUTH PRIMARY CARE ALLIANCE LTD       0.29941
# 1392                                CCCT 2       0.28079
# 1393                      EDWIN HOUSE IPDU       0.20567
#
# [1394 rows x 2 columns]

# %%
changetype_to_int(Service_Total_Sales_df, 'Total Sales')

# %% [markdown]
# ### Service centre visits

# %%
con = PostgresConnection().getConnection()
cur = con.cursor()

insert_stmt = """SELECT s.practice_name, COUNT(s.practice_name)
FROM epd_snow.fact_table as f
INNER JOIN epd_snow.service as s ON s.practice_code = f.practice_code
GROUP BY s.practice_name
ORDER BY COUNT(s.practice_name) DESC"""

cur.execute(insert_stmt)
records = cur.fetchall()
service_df = pd.DataFrame(list(records), columns=['Service Name', 'Count'])
service_df.drop(service_df[(service_df['Service Name'] == 'UNIDENTIFIED DOCTORS')].index, inplace=True)
service_df
# Out:
# Connection to DB established!
#                                   Service Name  Count
# 0                         HAXBY GROUP PRACTICE   4131
# 2                      ANCORA MEDICAL PRACTICE   2610
# 3                            RIVERSIDE SURGERY   2385
# 4                       WINGATE MEDICAL CENTRE   2280
# 5              CAMBRIDGE AVENUE MEDICAL CENTRE   2227
# ...                                        ...    ...
# 1389                 CUMBRIA PARTNERSHIP NHSFT      1
# 1390                          NT&H COMM DIAB N      1
# 1391         ADULT LEARNING DISABILITY SERVICE      1
# 1392  CSRPRESTON COMMUNITY DERMATOLOGY SERVICE      1
# 1393                         ADULT ADHD HALTON      1
#
# [1393 rows x 2 columns]

# %% [markdown]
# ### Service centre visits wise sales

# %%
con = PostgresConnection().getConnection()
cur = con.cursor()

insert_stmt = """SELECT s.practice_name, SUM(f.actual_cost) as Total_Sales
                FROM epd_snow.fact_table as f
                INNER JOIN epd_snow.service as s ON s.practice_code = f.practice_code
                GROUP BY s.practice_name
                ORDER BY COUNT(s.practice_name) desc"""
# psycopg2.extras.execute_batch(cur, insert_stmt, fact_data.values)
cur.execute(insert_stmt)
records = cur.fetchall()
Service_Total_Sales_df = pd.DataFrame(list(records), columns=['Service', 'Total Sales'])
Service_Total_Sales_df
# Out:
# Connection to DB established!
#                                        Service   Total Sales
# 0                         HAXBY GROUP PRACTICE  344985.68757
# 1                         UNIDENTIFIED DOCTORS  209758.33134
# 2                      ANCORA MEDICAL PRACTICE  159862.29859
# 3                            RIVERSIDE SURGERY  105789.81445
# 4                       WINGATE MEDICAL CENTRE  106876.95329
# ...                                        ...           ...
# 1389                 CUMBRIA PARTNERSHIP NHSFT       4.10988
# 1390                          NT&H COMM DIAB N      86.92231
# 1391         ADULT LEARNING DISABILITY SERVICE       4.50558
# 1392  CSRPRESTON COMMUNITY DERMATOLOGY SERVICE       2.16299
# 1393                         ADULT ADHD HALTON      25.64827
#
# [1394 rows x 2 columns]

# %% [markdown]
# ### Chapter-plus-Code with quantity

# %%
con = PostgresConnection().getConnection()
cur = con.cursor()

insert_stmt = """SELECT BNF_CHAPTER_PLUS_CODE, SUM(TOTAL_QUANTITY) as Total_Quantity
                FROM epd_snow.fact_table as f
                INNER JOIN epd_snow.prescription as p ON p.prescription_key = f.prescription_key
                GROUP BY BNF_CHAPTER_PLUS_CODE
                ORDER BY BNF_CHAPTER_PLUS_CODE"""
# psycopg2.extras.execute_batch(cur, insert_stmt, fact_data.values)
cur.execute(insert_stmt)
records = cur.fetchall()
chapter_quantity_df = pd.DataFrame(list(records), columns=['Chapter_and_Code', 'Total Quantity'])
chapter_quantity_df
# Out:
# Connection to DB established!
#                                      Chapter_and_Code Total Quantity
# 0                        01: Gastro-Intestinal System      8935947.0
# 1                           02: Cardiovascular System     11421548.0
# 2                              03: Respiratory System      1431755.0
# 3                          04: Central Nervous System     20241398.4
# 4                                      05: Infections      1452544.0
# 5                                06: Endocrine System      5349853.0
# 6   07: Obstetrics, Gynaecology and Urinary-Tract ...      1253828.0
# 7         08: Malignant Disease and Immunosuppression       173362.0
# 8                             09: Nutrition and Blood     29110944.5
# 9              10: Musculoskeletal and Joint Diseases      1876844.0
# 10                                            11: Eye       239266.0
# 11                       12: Ear, Nose and Oropharynx       178330.6
# 12                                           13: Skin      4369759.0
# 13            14: Immunological Products and Vaccines         7794.0
# 14                                    15: Anaesthesia        22462.5
# 15                   19: Other Drugs and Preparations       503181.0
# 16                                      20: Dressings       200736.5
# 17                                     21: Appliances      5210504.0
# 18                        22: Incontinence Appliances        52235.0
# 19                               23: Stoma Appliances       712380.5

# %% [markdown]
# ### PCO wise chapter-plus-code sales

# %%
con = PostgresConnection().getConnection()
cur = con.cursor()

insert_stmt = """SELECT PCO_NAME,BNF_CHAPTER_PLUS_CODE, SUM(ACTUAL_COST) as Total_Sales
                FROM epd_snow.fact_table as f
                INNER JOIN epd_snow.prescription as p ON p.prescription_key = f.prescription_key
                INNER JOIN epd_snow.location as l ON l.location_key = f.location_key
                GROUP BY PCO_NAME,BNF_CHAPTER_PLUS_CODE
                ORDER BY PCO_NAME, Total_Sales desc"""
# psycopg2.extras.execute_batch(cur, insert_stmt, fact_data.values)
cur.execute(insert_stmt)
records = cur.fetchall()
chapter_quantity_df = pd.DataFrame(list(records), columns=['PCO','Chapter_and_Code', 'Total Sales'])
chapter_quantity_df
# Out:
# Connection to DB established!
#                                            PCO            Chapter_and_Code  \
# 0                                 ABOUT HEALTH              21: Appliances
# 1                                 ABOUT HEALTH                    13: Skin
# 2                AIREDALE NHS FOUNDATION TRUST               20: Dressings
# 3                AIREDALE NHS FOUNDATION TRUST              21: Appliances
# 4                AIREDALE NHS FOUNDATION TRUST        23: Stoma Appliances
# ...                                        ...                         ...
# 2610  YORK AND SCARBOROUGH TEACHING HOSPITALS               21: Appliances
# 2611  YORK AND SCARBOROUGH TEACHING HOSPITALS              15: Anaesthesia
# 2612  YORK AND SCARBOROUGH TEACHING HOSPITALS   04: Central Nervous System
# 2613  YORK AND SCARBOROUGH TEACHING HOSPITALS                     13: Skin
# 2614             YORK TEACHING HOSPITAL NHS FT   02: Cardiovascular System
#
#      Total Sales
# 0       34.09126
# 1        8.81415
# 2      216.93694
# 3       33.78504
# 4       14.94564
# ...          ...
# 2610    17.47516
# 2611     6.08102
# 2612     4.97991
# 2613     3.16504
# 2614   269.83401
#
# [2615 rows x 3 columns]

# %% [markdown]
# ### Count of PCOs against STPs

# %%
con = PostgresConnection().getConnection()
cur = con.cursor()

insert_stmt = """SELECT REGIONAL_OFFICE_NAME,STP_NAME, PCO_NAME,PRACTICE_NAME,SUM(ACTUAL_COST)
                FROM epd_snow.fact_table as f
                INNER JOIN epd_snow.location as l ON l.location_key = f.location_key
                INNER JOIN epd_snow.service as s ON s.practice_code = f.practice_code
                GROUP BY REGIONAL_OFFICE_NAME, STP_NAME, PCO_NAME,PRACTICE_NAME
        aa        ORDER BY SUM(ACTUAL_COST) desc """
# psycopg2.extras.execute_batch(cur, insert_stmt, fact_data.values)
cur.execute(insert_stmt)
records = cur.fetchall()
chapter_quantity_df = pd.DataFrame(list(records), columns=['REGIONAL_OFFICE_NAME','STP_NAME','PCO_NAME','PRACTICE_NAME', 'Sales'])

chapter_quantity_df.groupby('STP_NAME')

pco_count = chapter_quantity_df['PCO_NAME'].value_counts()
pco_count.sum()
# Out:
# Connection to DB established!
# 2040

# %% [markdown]
# ### Sales from each particular locations

# %%
con = PostgresConnection().getConnection()
cur = con.cursor()

insert_stmt = """SELECT REGIONAL_OFFICE_NAME,STP_NAME, PCO_NAME,PRACTICE_NAME,SUM(ACTUAL_COST)
                FROM epd_snow.fact_table as f
                INNER JOIN epd_snow.location as l ON l.location_key = f.location_key
                INNER JOIN epd_snow.service as s ON s.practice_code = f.practice_code
                GROUP BY REGIONAL_OFFICE_NAME, STP_NAME, PCO_NAME,PRACTICE_NAME
                ORDER BY SUM(ACTUAL_COST) desc """
# psycopg2.extras.execute_batch(cur, insert_stmt, fact_data.values)
cur.execute(insert_stmt)
records = cur.fetchall()
chapter_quantity_df = pd.DataFrame(list(records), columns=['REGIONAL_OFFICE_NAME','STP_NAME','PCO_NAME','PRACTICE_NAME', 'Sales'])

chapter_quantity_df
# Out:
# Connection to DB established!
#           REGIONAL_OFFICE_NAME                                  STP_NAME  \
# 0     NORTH EAST AND YORKSHIRE                  HUMBER, COAST & VALE STP
# 1                 UNIDENTIFIED                              UNIDENTIFIED
# 2     NORTH EAST AND YORKSHIRE                  HUMBER, COAST & VALE STP
# 3     NORTH EAST AND YORKSHIRE                  HUMBER, COAST & VALE STP
# 4     NORTH EAST AND YORKSHIRE           SOUTH YORKSHIRE & BASSETLAW STP
# ...                        ...                                       ...
# 2035           EAST OF ENGLAND                   MID AND SOUTH ESSEX STP
# 2036  NORTH EAST AND YORKSHIRE           SOUTH YORKSHIRE & BASSETLAW STP
# 2037                SOUTH EAST  NHS HAMPSHIRE AND ISLE OF WIGHT INTEGRAT
# 2038  NORTH EAST AND YORKSHIRE  NHS WEST YORKSHIRE INTEGRATED CARE BOARD
# 2039                  MIDLANDS      NOTTINGHAM & NOTTINGHAMSHIRE H&C STP
#
#                                       PCO_NAME  \
# 0                             VALE OF YORK CCG
# 1                                 UNIDENTIFIED
# 2                       NORTH LINCOLNSHIRE CCG
# 3                       NORTH LINCOLNSHIRE CCG
# 4                                ROTHERHAM CCG
# ...                                        ...
# 2035                BASILDON AND BRENTWOOD CCG
# 2036                RDASH NHS FOUNDATION TRUST
# 2037  NHS HAMPSHIRE AND ISLE OF WIGHT ICB - 10
# 2038             AIREDALE NHS FOUNDATION TRUST
# 2039                                 FRAMEWORK
#
#                              PRACTICE_NAME         Sales
# 0                     HAXBY GROUP PRACTICE  326341.39404
# 1                     UNIDENTIFIED DOCTORS  199556.64944
# 2                  ANCORA MEDICAL PRACTICE  150493.19887
# 3          CAMBRIDGE AVENUE MEDICAL CENTRE  122966.11329
# 4                DINNINGTON GROUP PRACTICE  116034.61589
# ...                                    ...           ...
# 2035                  UNIDENTIFIED DOCTORS       0.32647
# 2036            DONCASTER CLOZAPINE CLINIC       0.30773
# 2037  PORTSMOUTH PRIMARY CARE ALLIANCE LTD       0.29941
# 2038                                CCCT 2       0.28079
# 2039                      EDWIN HOUSE IPDU       0.20567
#
# [2040 rows x 5 columns]

# %% [markdown]
# ### In 2021, month wise prescription from each regions

# %%
con = PostgresConnection().getConnection()
cur=con.cursor()
select_stmt="SELECT REGIONAL_OFFICE_NAME,SUM(f.TOTAL_QUANTITY) as TOTAL_QUANTITY,T.MONTH "\
"FROM epd_snow.FACT_TABLE as f "\
"inner JOIN epd_snow.LOCATION as L ON L.LOCATION_KEY = f.LOCATION_KEY "\
"inner JOIN epd_snow.TIME as T ON T.TIME_KEY = f.TIME_KEY "\
"where T.YEAR = 2021"\
"GROUP BY (L.REGIONAL_OFFICE_NAME, T.MONTH)"\
"ORDER BY T.MONTH "
cur.execute(select_stmt)
records=cur.fetchall()
Total_Quantity_df = pd.DataFrame(list(records), columns=['Region', 'Total Quantity', 'month'])
Total_Quantity_df
# Out:
# Connection to DB established!
#                       Region Total Quantity  month
# 0            EAST OF ENGLAND      2890271.3      1
# 1                   MIDLANDS        15031.5      1
# 2                 SOUTH EAST        23592.0      1
# 3                 SOUTH WEST       132789.0      1
# 4               UNIDENTIFIED       104877.0      1
# ..                       ...            ...    ...
# 84  NORTH EAST AND YORKSHIRE      1437111.0     12
# 85                NORTH WEST       996858.0     12
# 86                SOUTH EAST       209855.0     12
# 87                SOUTH WEST        16726.0     12
# 88              UNIDENTIFIED        53289.0     12
#
# [89 rows x 3 columns]

# %% [markdown]
# ### In 2021, month wise sales of drugs for the departments and their patint visits

# %%
con = PostgresConnection().getConnection()
cur=con.cursor() 
select_stmt="SELECT T.MONTH, BNF_CHAPTER_PLUS_CODE, COUNT(BNF_CHAPTER_PLUS_CODE), SUM(f.ACTUAL_COST) as Sales "\
"FROM epd_snow.FACT_TABLE as f "\
"inner JOIN epd_snow.prescription as p ON p.prescription_key = f.prescription_key "\
"inner JOIN epd_snow.TIME as T ON T.TIME_KEY = f.TIME_KEY "\
"where T.YEAR = 2021"\
"GROUP BY (BNF_CHAPTER_PLUS_CODE, T.MONTH)"\
"ORDER BY T.MONTH,  Sales desc"
cur.execute(select_stmt)
records=cur.fetchall()
Total_Quantity_df = pd.DataFrame(list(records), columns=['MONTH','BNF CHAPTER','Count', 'Sales'])
Total_Quantity_df = Total_Quantity_df.groupby('MONTH').head(3)
Total_Quantity_df
# Out:
# Connection to DB established!
#      MONTH                 BNF CHAPTER  Count        Sales
# 0        1  04: Central Nervous System   2601  81906.77993
# 1        1        06: Endocrine System    954  62962.97316
# 2        1   02: Cardiovascular System   1532  58358.78996
# 20       2   02: Cardiovascular System   1532  72948.49127
# 21       2  04: Central Nervous System   2560  67763.99800
# 22       2        06: Endocrine System    930  58632.36116
# 40       3   02: Cardiovascular System   1423  97094.73942
# 41       3  04: Central Nervous System   2616  93194.73700
# 42       3        06: Endocrine System    906  75051.91919
# 60       4  04: Central Nervous System   2500  75910.76355
# 61       4   02: Cardiovascular System   1479  66581.04023
# 62       4        06: Endocrine System    946  60139.92870
# 80       5  04: Central Nervous System   2554  74965.15860
# 81       5        06: Endocrine System    929  70700.17553
# 82       5   02: Cardiovascular System   1603  69527.29848
# 100      6  04: Central Nervous System   2507  84002.04313
# 101      6        06: Endocrine System    937  60324.31457
# 102      6   02: Cardiovascular System   1520  60283.55644
# 120      7  04: Central Nervous System   2598  77451.51589
# 121      7        06: Endocrine System    899  68461.56524
# 122      7   02: Cardiovascular System   1463  65446.22635
# 140      8   02: Cardiovascular System   1510  88579.09848
# 141      8  04: Central Nervous System   2590  82386.99455
# 142      8        06: Endocrine System    924  61461.02799
# 160      9   02: Cardiovascular System   1452  82380.08419
# 161      9  04: Central Nervous System   2561  77563.48176
# 162      9        06: Endocrine System    891  55836.69266
# 180     10   02: Cardiovascular System   1535  72364.14881
# 181     10  04: Central Nervous System   2565  71215.04949
# 182     10      03: Respiratory System    540  59710.00717
# 200     11  04: Central Nervous System   2660  85002.42406
# 201     11        06: Endocrine System    915  67891.75404
# 202     11   02: Cardiovascular System   1365  63839.15350
# 220     12  04: Central Nervous System   2550  72840.88534
# 221     12        06: Endocrine System    953  63965.19045
# 222     12   02: Cardiovascular System   1464  61338.06987

# %% [markdown]
# ### In 2021, sales made from drugs sold for a particular department

# %%
con = PostgresConnection().getConnection()
cur=con.cursor() 
select_stmt="SELECT T.MONTH, BNF_CHAPTER_PLUS_CODE, SUM(f.ACTUAL_COST) as Sales "\
"FROM epd_snow.FACT_TABLE as f "\
"inner JOIN epd_snow.prescription as p ON p.prescription_key = f.prescription_key "\
"inner JOIN epd_snow.TIME as T ON T.TIME_KEY = f.TIME_KEY "\
"where T.YEAR = 2021 AND BNF_CHAPTER_PLUS_CODE= '04: Central Nervous System' "\
"GROUP BY (BNF_CHAPTER_PLUS_CODE, T.MONTH)"\
"ORDER BY T.MONTH, Sales DESC"
cur.execute(select_stmt)
records=cur.fetchall()
Total_Quantity_df = pd.DataFrame(list(records), columns=['MONTH','BNF_CHAPTER', 'Sales'])
Total_Quantity_df = Total_Quantity_df.groupby('MONTH').head(1)
Total_Quantity_df
# Out:
# Connection to DB established!
#     MONTH                 BNF_CHAPTER        Sales
# 0       1  04: Central Nervous System  81906.77993
# 1       2  04: Central Nervous System  67763.99800
# 2       3  04: Central Nervous System  93194.73700
# 3       4  04: Central Nervous System  75910.76355
# 4       5  04: Central Nervous System  74965.15860
# 5       6  04: Central Nervous System  84002.04313
# 6       7  04: Central Nervous System  77451.51589
# 7       8  04: Central Nervous System  82386.99455
# 8       9  04: Central Nervous System  77563.48176
# 9      10  04: Central Nervous System  71215.04949
# 10     11  04: Central Nervous System  85002.42406
# 11     12  04: Central Nervous System  72840.88534

# %% [markdown]
# ### In 2021, departments with most patient visits

# %%
con = PostgresConnection().getConnection()
cur=con.cursor() 
select_stmt="SELECT T.MONTH,BNF_CHAPTER_PLUS_CODE, COUNT(BNF_CHAPTER_PLUS_CODE) "\
"FROM epd_snow.FACT_TABLE as f "\
"inner JOIN epd_snow.prescription as p ON p.prescription_key = f.prescription_key "\
"inner JOIN epd_snow.TIME as T ON T.TIME_KEY = f.TIME_KEY "\
"where T.YEAR = 2021"\
"GROUP BY (BNF_CHAPTER_PLUS_CODE, T.MONTH)"\
"ORDER BY T.MONTH, COUNT(BNF_CHAPTER_PLUS_CODE) desc  "
cur.execute(select_stmt)
records=cur.fetchall()
Total_Quantity_df = pd.DataFrame(list(records), columns=['MONTH','BNF CHAPTER', 'COUNT'])
Total_Quantity_df = Total_Quantity_df.groupby('MONTH').head(3)

Total_Quantity_df
# Out:
# Connection to DB established!
#      MONTH                 BNF CHAPTER  COUNT
# 0        1  04: Central Nervous System   2601
# 1        1   02: Cardiovascular System   1532
# 2        1        06: Endocrine System    954
# 20       2  04: Central Nervous System   2560
# 21       2   02: Cardiovascular System   1532
# 22       2        06: Endocrine System    930
# 40       3  04: Central Nervous System   2616
# 41       3   02: Cardiovascular System   1423
# 42       3        06: Endocrine System    906
# 60       4  04: Central Nervous System   2500
# 61       4   02: Cardiovascular System   1479
# 62       4        06: Endocrine System    946
# 80       5  04: Central Nervous System   2554
# 81       5   02: Cardiovascular System   1603
# 82       5        06: Endocrine System    929
# 100      6  04: Central Nervous System   2507
# 101      6   02: Cardiovascular System   1520
# 102      6        06: Endocrine System    937
# 120      7  04: Central Nervous System   2598
# 121      7   02: Cardiovascular System   1463
# 122      7        06: Endocrine System    899
# 140      8  04: Central Nervous System   2590
# 141      8   02: Cardiovascular System   1510
# 142      8        06: Endocrine System    924
# 160      9  04: Central Nervous System   2561
# 161      9   02: Cardiovascular System   1452
# 162      9        06: Endocrine System    891
# 180     10  04: Central Nervous System   2565
# 181     10   02: Cardiovascular System   1535
# 182     10        06: Endocrine System    933
# 200     11  04: Central Nervous System   2660
# 201     11   02: Cardiovascular System   1365
# 202     11        06: Endocrine System    915
# 220     12  04: Central Nervous System   2550
# 221     12   02: Cardiovascular System   1464
# 222     12        06: Endocrine System    953

# %%
con = PostgresConnection().getConnection()
cur=con.cursor() 
select_stmt="SELECT T.MONTH,BNF_CHAPTER_PLUS_CODE, COUNT(BNF_CHAPTER_PLUS_CODE) "\
"FROM epd_snow.FACT_TABLE as f "\
"inner JOIN epd_snow.prescription as p ON p.prescription_key = f.prescription_key "\
"inner JOIN epd_snow.TIME as T ON T.TIME_KEY = f.TIME_KEY "\
"where T.YEAR = 2021"\
"GROUP BY (BNF_CHAPTER_PLUS_CODE, T.MONTH)"\
"ORDER BY T.MONTH, COUNT(BNF_CHAPTER_PLUS_CODE) desc  "
cur.execute(select_stmt)
records=cur.fetchall()
Total_Quantity_df = pd.DataFrame(list(records), columns=['MONTH','BNF CHAPTER', 'COUNT'])
Total_Quantity_df = Total_Quantity_df.groupby('MONTH').head(3)
ptest = pd.DataFrame(Total_Quantity_df.values, columns=['MONTH','BNF CHAPTER', 'COUNT'])


Total_Quantity_df = {k: g['COUNT'].tolist() for k,g in ptest.groupby('BNF CHAPTER')}


Total_Quantity_df
# Out:
# Connection to DB established!
# {'02: Cardiovascular System': [1532,
#   1532,
#   1423,
#   1479,
#   1603,
#   1520,
#   1463,
#   1510,
#   1452,
#   1535,
#   1365,
#   1464],
#  '04: Central Nervous System': [2601,
#   2560,
#   2616,
#   2500,
#   2554,
#   2507,
#   2598,
#   2590,
#   2561,
#   2565,
#   2660,
#   2550],
#  '06: Endocrine System': [954,
#   930,
#   906,
#   946,
#   929,
#   937,
#   899,
#   924,
#   891,
#   933,
#   915,
#   953]}

# %% [markdown]
# ### STP wise prescriptions generated and sales made from them

# %%
con = PostgresConnection().getConnection()
cur=con.cursor() 
select_stmt="""SELECT location.stp_name,COUNT(prescription.bnf_code), SUM(actual_cost) as sales
FROM epd_snow.location
JOIN epd_snow.fact_table ON fact_table.location_key = location.location_key
JOIN epd_snow.prescription ON fact_table.prescription_key = prescription.prescription_key
GROUP BY (location.stp_name, prescription.bnf_code)
ORDER BY COUNT(prescription.bnf_code) DESC """

cur.execute(select_stmt)
records=cur.fetchall()
records
# Out:
# Connection to DB established!
# [('HUMBER, COAST & VALE STP', 185, Decimal('4198.34865')),
#  ('HUMBER, COAST & VALE STP', 184, Decimal('9763.28606')),
#  ('HUMBER, COAST & VALE STP', 156, Decimal('2625.17063')),
#  ('MID AND SOUTH ESSEX STP', 154, Decimal('2085.83261')),
#  ('CUMBRIA & NORTH EAST STP', 152, Decimal('9055.21926')),
#  ('MID AND SOUTH ESSEX STP', 148, Decimal('2187.56790')),
#  ('MID AND SOUTH ESSEX STP', 144, Decimal('924.60448')),
#  ('MID AND SOUTH ESSEX STP', 135, Decimal('5523.65724')),
#  ('HUMBER, COAST & VALE STP', 135, Decimal('9802.44969')),
#  ('SUSSEX & EAST SURREY STP', 135, Decimal('11191.04791')),
#  ('MID AND SOUTH ESSEX STP', 129, Decimal('4176.71805')),
#  ('MID AND SOUTH ESSEX STP', 129, Decimal('4721.53938')),
#  ('HUMBER, COAST & VALE STP', 123, Decimal('3767.93269')),
#  ('HUMBER, COAST & VALE STP', 122, Decimal('395.57069')),
#  ('MID AND SOUTH ESSEX STP', 120, Decimal('6533.14427')),
#  ('MID AND SOUTH ESSEX STP', 119, Decimal('1463.65210')),
#  ('HUMBER, COAST & VALE STP', 119, Decimal('1123.44218')),
#  ('HUMBER, COAST & VALE STP', 112, Decimal('2517.09758')),
#  ('MID AND SOUTH ESSEX STP', 112, Decimal('4486.93636')),
#  ('MID AND SOUTH ESSEX STP', 111, Decimal('788.48932')),
#  ('HUMBER, COAST & VALE STP', 108, Decimal('1307.96129')),
#  ('SUSSEX & EAST SURREY STP', 107, Decimal('4995.94227')),
#  ('HUMBER, COAST & VALE STP', 104, Decimal('2170.79871')),
#  ('HUMBER, COAST & VALE STP', 103, Decimal('2293.81646')),
#  ('MID AND SOUTH ESSEX STP', 101, Decimal('3906.77516')),
#  ('HUMBER, COAST & VALE STP', 98, Decimal('2966.98877')),
#  ('HUMBER, COAST & VALE STP', 97, Decimal('895.04065')),
#  ('MID AND SOUTH ESSEX STP', 96, Decimal('218.36836')),
#  ('MID AND SOUTH ESSEX STP', 96, Decimal('7013.55018')),
#  ('MID AND SOUTH ESSEX STP', 95, Decimal('1978.73384')),
#  ('MID AND SOUTH ESSEX STP', 94, Decimal('668.01527')),
#  ('HUMBER, COAST & VALE STP', 94, Decimal('821.87993')),
#  ('HUMBER, COAST & VALE STP', 94, Decimal('1586.57770')),
#  ('HUMBER, COAST & VALE STP', 93, Decimal('1740.60663')),
#  ('HUMBER, COAST & VALE STP', 92, Decimal('9896.01629')),
#  ('EAST LONDON HEALTH & CARE P/SHIP STP', 92, Decimal('3730.85697')),
#  ('MID AND SOUTH ESSEX STP', 92, Decimal('1072.15921')),
#  ('MID AND SOUTH ESSEX STP', 91, Decimal('1521.22333')),
#  ('MID AND SOUTH ESSEX STP', 90, Decimal('3221.66846')),
#  ('NORTH LONDON PARTNERS IN H&C STP', 90, Decimal('3149.65276')),
#  ('HUMBER, COAST & VALE STP', 90, Decimal('774.64781')),
#  ('HUMBER, COAST & VALE STP', 89, Decimal('4032.61718')),
#  ('HUMBER, COAST & VALE STP', 89, Decimal('1878.74630')),
#  ('MID AND SOUTH ESSEX STP', 89, Decimal('4050.66745')),
#  ('MID AND SOUTH ESSEX STP', 88, Decimal('1179.60139')),
#  ('HUMBER, COAST & VALE STP', 88, Decimal('2991.95836')),
#  ('HUMBER, COAST & VALE STP', 87, Decimal('1768.44932')),
#  ('HUMBER, COAST & VALE STP', 87, Decimal('4668.56651')),
#  ('MID AND SOUTH ESSEX STP', 87, Decimal('6729.93343')),
#  ('MID AND SOUTH ESSEX STP', 85, Decimal('1666.97257')),
#  ('MID AND SOUTH ESSEX STP', 85, Decimal('1113.63325')),
#  ('CHESHIRE & MERSEYSIDE STP', 85, Decimal('331.63961')),
#  ('HUMBER, COAST & VALE STP', 84, Decimal('1875.87108')),
#  ('MID AND SOUTH ESSEX STP', 84, Decimal('843.70469')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 83, Decimal('539.85354')),
#  ('HUMBER, COAST & VALE STP', 83, Decimal('690.04831')),
#  ('HUMBER, COAST & VALE STP', 82, Decimal('5069.47141')),
#  ('MID AND SOUTH ESSEX STP', 82, Decimal('1303.78096')),
#  ('MID AND SOUTH ESSEX STP', 81, Decimal('372.29653')),
#  ('DEVON STP', 81, Decimal('1452.54583')),
#  ('CHESHIRE & MERSEYSIDE STP', 81, Decimal('870.92949')),
#  ('HUMBER, COAST & VALE STP', 81, Decimal('8599.76540')),
#  ('HUMBER, COAST & VALE STP', 80, Decimal('1668.22850')),
#  ('HUMBER, COAST & VALE STP', 80, Decimal('4005.95927')),
#  ('MID AND SOUTH ESSEX STP', 80, Decimal('3203.80554')),
#  ('MID AND SOUTH ESSEX STP', 79, Decimal('824.08425')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 79, Decimal('1711.06919')),
#  ('HUMBER, COAST & VALE STP', 79, Decimal('1109.80795')),
#  ('CHESHIRE & MERSEYSIDE STP', 79, Decimal('1030.71228')),
#  ('HUMBER, COAST & VALE STP', 79, Decimal('4961.89588')),
#  ('CHESHIRE & MERSEYSIDE STP', 78, Decimal('1045.55426')),
#  ('CHESHIRE & MERSEYSIDE STP', 76, Decimal('2642.19318')),
#  ('HUMBER, COAST & VALE STP', 76, Decimal('3296.75895')),
#  ('MID AND SOUTH ESSEX STP', 76, Decimal('759.04655')),
#  ('MID AND SOUTH ESSEX STP', 75, Decimal('275.25987')),
#  ('MID AND SOUTH ESSEX STP', 75, Decimal('576.94660')),
#  ('HUMBER, COAST & VALE STP', 75, Decimal('7852.61390')),
#  ('HUMBER, COAST & VALE STP', 74, Decimal('1132.98148')),
#  ('HUMBER, COAST & VALE STP', 74, Decimal('1074.03473')),
#  ('CHESHIRE & MERSEYSIDE STP', 74, Decimal('906.56446')),
#  ('MID AND SOUTH ESSEX STP', 74, Decimal('929.32576')),
#  ('MID AND SOUTH ESSEX STP', 73, Decimal('2711.01817')),
#  ('MID AND SOUTH ESSEX STP', 72, Decimal('594.40510')),
#  ('MID AND SOUTH ESSEX STP', 72, Decimal('1410.98554')),
#  ('MID AND SOUTH ESSEX STP', 72, Decimal('1415.65979')),
#  ('HUMBER, COAST & VALE STP', 72, Decimal('2803.17574')),
#  ('HUMBER, COAST & VALE STP', 72, Decimal('960.03049')),
#  ('HUMBER, COAST & VALE STP', 71, Decimal('774.16307')),
#  ('HUMBER, COAST & VALE STP', 71, Decimal('1577.32540')),
#  ('MID AND SOUTH ESSEX STP', 70, Decimal('1256.89101')),
#  ('MID AND SOUTH ESSEX STP', 70, Decimal('903.33550')),
#  ('MID AND SOUTH ESSEX STP', 69, Decimal('795.16944')),
#  ('MID AND SOUTH ESSEX STP', 69, Decimal('1487.23276')),
#  ('HUMBER, COAST & VALE STP', 69, Decimal('4719.82978')),
#  ('CHESHIRE & MERSEYSIDE STP', 69, Decimal('3530.66792')),
#  ('CHESHIRE & MERSEYSIDE STP', 68, Decimal('567.91732')),
#  ('MID AND SOUTH ESSEX STP', 68, Decimal('3215.51511')),
#  ('MID AND SOUTH ESSEX STP', 68, Decimal('1083.56865')),
#  ('MID AND SOUTH ESSEX STP', 68, Decimal('697.18415')),
#  ('MID AND SOUTH ESSEX STP', 67, Decimal('1365.51310')),
#  ('MID AND SOUTH ESSEX STP', 67, Decimal('638.93407')),
#  ('HUMBER, COAST & VALE STP', 67, Decimal('944.14121')),
#  ('CHESHIRE & MERSEYSIDE STP', 67, Decimal('4118.45810')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 67, Decimal('4497.46970')),
#  ('HUMBER, COAST & VALE STP', 67, Decimal('892.43146')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 66, Decimal('608.05900')),
#  ('MID AND SOUTH ESSEX STP', 65, Decimal('5804.97844')),
#  ('MID AND SOUTH ESSEX STP', 65, Decimal('2760.61931')),
#  ('MID AND SOUTH ESSEX STP', 65, Decimal('1626.93386')),
#  ('MID AND SOUTH ESSEX STP', 65, Decimal('1214.22373')),
#  ('MID AND SOUTH ESSEX STP', 65, Decimal('1645.59900')),
#  ('MID AND SOUTH ESSEX STP', 64, Decimal('737.81621')),
#  ('MID AND SOUTH ESSEX STP', 64, Decimal('4719.67264')),
#  ('MID AND SOUTH ESSEX STP', 64, Decimal('7297.61880')),
#  ('HUMBER, COAST & VALE STP', 64, Decimal('777.48577')),
#  ('HUMBER, COAST & VALE STP', 64, Decimal('255.51138')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 64, Decimal('1539.50678')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 64, Decimal('475.24346')),
#  ('CHESHIRE & MERSEYSIDE STP', 64, Decimal('2491.39271')),
#  ('CHESHIRE & MERSEYSIDE STP', 63, Decimal('1083.95662')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 63, Decimal('1355.63426')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 63, Decimal('3518.30532')),
#  ('HUMBER, COAST & VALE STP', 63, Decimal('1101.18224')),
#  ('MID AND SOUTH ESSEX STP', 63, Decimal('1908.75627')),
#  ('MID AND SOUTH ESSEX STP', 63, Decimal('3483.52812')),
#  ('MID AND SOUTH ESSEX STP', 63, Decimal('333.43744')),
#  ('MID AND SOUTH ESSEX STP', 63, Decimal('2541.16716')),
#  ('MID AND SOUTH ESSEX STP', 62, Decimal('647.97508')),
#  ('MID AND SOUTH ESSEX STP', 62, Decimal('2198.93989')),
#  ('MID AND SOUTH ESSEX STP', 62, Decimal('389.49288')),
#  ('CHESHIRE & MERSEYSIDE STP', 62, Decimal('1452.86271')),
#  ('HUMBER, COAST & VALE STP', 61, Decimal('12479.56761')),
#  ('CHESHIRE & MERSEYSIDE STP', 61, Decimal('2894.87676')),
#  ('HUMBER, COAST & VALE STP', 61, Decimal('1341.24029')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 61, Decimal('956.00421')),
#  ('CHESHIRE & MERSEYSIDE STP', 61, Decimal('913.40721')),
#  ('HUMBER, COAST & VALE STP', 61, Decimal('901.30802')),
#  ('HUMBER, COAST & VALE STP', 61, Decimal('1680.93917')),
#  ('MID AND SOUTH ESSEX STP', 61, Decimal('1001.30584')),
#  ('MID AND SOUTH ESSEX STP', 61, Decimal('1088.85549')),
#  ('MID AND SOUTH ESSEX STP', 60, Decimal('2301.27663')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 60, Decimal('149.23313')),
#  ('HUMBER, COAST & VALE STP', 60, Decimal('1994.56087')),
#  ('HUMBER, COAST & VALE STP', 60, Decimal('991.27364')),
#  ('HUMBER, COAST & VALE STP', 59, Decimal('1593.20536')),
#  ('HUMBER, COAST & VALE STP', 59, Decimal('665.05832')),
#  ('HUMBER, COAST & VALE STP', 59, Decimal('1188.24114')),
#  ('HUMBER, COAST & VALE STP', 59, Decimal('1276.28190')),
#  ('CHESHIRE & MERSEYSIDE STP', 59, Decimal('2980.41969')),
#  ('CHESHIRE & MERSEYSIDE STP', 59, Decimal('370.73096')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 59, Decimal('2262.69320')),
#  ('MID AND SOUTH ESSEX STP', 59, Decimal('1082.78459')),
#  ('MID AND SOUTH ESSEX STP', 59, Decimal('2254.58838')),
#  ('MID AND SOUTH ESSEX STP', 59, Decimal('2076.31074')),
#  ('MID AND SOUTH ESSEX STP', 58, Decimal('434.79262')),
#  ('MID AND SOUTH ESSEX STP', 58, Decimal('1450.05459')),
#  ('MID AND SOUTH ESSEX STP', 58, Decimal('155.30199')),
#  ('MID AND SOUTH ESSEX STP', 58, Decimal('926.46620')),
#  ('MID AND SOUTH ESSEX STP', 58, Decimal('623.19319')),
#  ('MID AND SOUTH ESSEX STP', 58, Decimal('1324.89548')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 58, Decimal('1086.40913')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 58, Decimal('4618.61541')),
#  ('HUMBER, COAST & VALE STP', 58, Decimal('2205.89344')),
#  ('CHESHIRE & MERSEYSIDE STP', 58, Decimal('7188.91064')),
#  ('HUMBER, COAST & VALE STP', 57, Decimal('773.71028')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 57, Decimal('1682.82173')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 57, Decimal('651.34362')),
#  ('HUMBER, COAST & VALE STP', 57, Decimal('1122.46274')),
#  ('HUMBER, COAST & VALE STP', 57, Decimal('1173.57072')),
#  ('MID AND SOUTH ESSEX STP', 57, Decimal('1087.52775')),
#  ('MID AND SOUTH ESSEX STP', 57, Decimal('758.86841')),
#  ('MID AND SOUTH ESSEX STP', 57, Decimal('611.76333')),
#  ('MID AND SOUTH ESSEX STP', 56, Decimal('4572.64458')),
#  ('MID AND SOUTH ESSEX STP', 56, Decimal('251.94756')),
#  ('MID AND SOUTH ESSEX STP', 56, Decimal('1149.22702')),
#  ('MID AND SOUTH ESSEX STP', 56, Decimal('4240.20183')),
#  ('CHESHIRE & MERSEYSIDE STP', 56, Decimal('145.85676')),
#  ('HUMBER, COAST & VALE STP', 56, Decimal('4162.39900')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 56, Decimal('467.20737')),
#  ('CHESHIRE & MERSEYSIDE STP', 56, Decimal('5152.81824')),
#  ('HUMBER, COAST & VALE STP', 56, Decimal('236.97376')),
#  ('HUMBER, COAST & VALE STP', 56, Decimal('870.51476')),
#  ('HUMBER, COAST & VALE STP', 56, Decimal('731.13006')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 55, Decimal('422.18172')),
#  ('CHESHIRE & MERSEYSIDE STP', 55, Decimal('1143.34040')),
#  ('HUMBER, COAST & VALE STP', 55, Decimal('7870.97300')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 55, Decimal('1127.52571')),
#  ('HUMBER, COAST & VALE STP', 55, Decimal('756.94048')),
#  ('HUMBER, COAST & VALE STP', 55, Decimal('968.67031')),
#  ('MID AND SOUTH ESSEX STP', 55, Decimal('1531.20157')),
#  ('MID AND SOUTH ESSEX STP', 55, Decimal('414.56595')),
#  ('MID AND SOUTH ESSEX STP', 54, Decimal('727.32804')),
#  ('MID AND SOUTH ESSEX STP', 54, Decimal('353.67034')),
#  ('MID AND SOUTH ESSEX STP', 54, Decimal('214.16299')),
#  ('MID AND SOUTH ESSEX STP', 54, Decimal('1166.81921')),
#  ('MID AND SOUTH ESSEX STP', 54, Decimal('570.69710')),
#  ('CHESHIRE & MERSEYSIDE STP', 54, Decimal('392.34692')),
#  ('HUMBER, COAST & VALE STP', 54, Decimal('2770.96762')),
#  ('HUMBER, COAST & VALE STP', 54, Decimal('5105.01322')),
#  ('HUMBER, COAST & VALE STP', 53, Decimal('4114.63949')),
#  ('HUMBER, COAST & VALE STP', 53, Decimal('3823.09428')),
#  ('HUMBER, COAST & VALE STP', 53, Decimal('528.07854')),
#  ('HUMBER, COAST & VALE STP', 53, Decimal('611.89735')),
#  ('HUMBER, COAST & VALE STP', 53, Decimal('1290.57389')),
#  ('HUMBER, COAST & VALE STP', 53, Decimal('6914.70484')),
#  ('MID AND SOUTH ESSEX STP', 53, Decimal('723.89180')),
#  ('MID AND SOUTH ESSEX STP', 53, Decimal('276.58687')),
#  ('MID AND SOUTH ESSEX STP', 53, Decimal('2486.93577')),
#  ('NHS NORTH EAST AND NORTH CUMBRIA INTEGRA', 52, Decimal('1725.92464')),
#  ('MID AND SOUTH ESSEX STP', 52, Decimal('1327.43220')),
#  ('HUMBER, COAST & VALE STP', 52, Decimal('1917.69223')),
#  ('HUMBER, COAST & VALE STP', 52, Decimal('1333.27246')),
#  ('HUMBER, COAST & VALE STP', 52, Decimal('406.56855')),
#  ('CHESHIRE & MERSEYSIDE STP', 52, Decimal('2102.63500')),
#  ('HUMBER, COAST & VALE STP', 52, Decimal('660.54065')),
#  ('HUMBER, COAST & VALE STP', 52, Decimal('1994.40558')),
#  ('HUMBER, COAST & VALE STP', 52, Decimal('203.75102')),
#  ('HUMBER, COAST & VALE STP', 51, Decimal('1226.06894')),
#  ('HUMBER, COAST & VALE STP', 51, Decimal('2049.57283')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 51, Decimal('1776.19740')),
#  ('HUMBER, COAST & VALE STP', 51, Decimal('1496.48136')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 51, Decimal('770.88657')),
#  ('HUMBER, COAST & VALE STP', 51, Decimal('5581.72141')),
#  ('HUMBER, COAST & VALE STP', 51, Decimal('1576.94750')),
#  ('MID AND SOUTH ESSEX STP', 51, Decimal('934.01505')),
#  ('MID AND SOUTH ESSEX STP', 51, Decimal('1640.47690')),
#  ('MID AND SOUTH ESSEX STP', 51, Decimal('237.87015')),
#  ('MID AND SOUTH ESSEX STP', 51, Decimal('1261.54956')),
#  ('MID AND SOUTH ESSEX STP', 51, Decimal('410.25171')),
#  ('MID AND SOUTH ESSEX STP', 50, Decimal('5450.12066')),
#  ('MID AND SOUTH ESSEX STP', 50, Decimal('1198.09142')),
#  ('MID AND SOUTH ESSEX STP', 50, Decimal('382.90887')),
#  ('MID AND SOUTH ESSEX STP', 50, Decimal('2614.64365')),
#  ('HUMBER, COAST & VALE STP', 50, Decimal('446.62395')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 50, Decimal('786.27604')),
#  ('HUMBER, COAST & VALE STP', 50, Decimal('573.22357')),
#  ('HUMBER, COAST & VALE STP', 50, Decimal('865.85695')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 50, Decimal('857.13923')),
#  ('HUMBER, COAST & VALE STP', 50, Decimal('187.94821')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 50, Decimal('642.56885')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 50, Decimal('752.68986')),
#  ('HUMBER, COAST & VALE STP', 50, Decimal('857.29456')),
#  ('HUMBER, COAST & VALE STP', 50, Decimal('3059.76674')),
#  ('HUMBER, COAST & VALE STP', 50, Decimal('675.92317')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 49, Decimal('3742.02128')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 49, Decimal('80.38846')),
#  ('CHESHIRE & MERSEYSIDE STP', 49, Decimal('157.09169')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 49, Decimal('414.72235')),
#  ('CHESHIRE & MERSEYSIDE STP', 49, Decimal('963.52591')),
#  ('HUMBER, COAST & VALE STP', 49, Decimal('1023.34474')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 48, Decimal('823.29067')),
#  ('CHESHIRE & MERSEYSIDE STP', 48, Decimal('1212.27977')),
#  ('HUMBER, COAST & VALE STP', 48, Decimal('3266.02988')),
#  ('HUMBER, COAST & VALE STP', 48, Decimal('2699.46168')),
#  ('HUMBER, COAST & VALE STP', 48, Decimal('3033.53668')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 48, Decimal('2888.04266')),
#  ('HUMBER, COAST & VALE STP', 48, Decimal('1875.71833')),
#  ('HUMBER, COAST & VALE STP', 48, Decimal('291.73458')),
#  ('HUMBER, COAST & VALE STP', 48, Decimal('455.90695')),
#  ('HUMBER, COAST & VALE STP', 48, Decimal('818.17634')),
#  ('HUMBER, COAST & VALE STP', 48, Decimal('1045.54554')),
#  ('HUMBER, COAST & VALE STP', 48, Decimal('9312.55051')),
#  ('SUSSEX & EAST SURREY STP', 48, Decimal('14029.51641')),
#  ('MID AND SOUTH ESSEX STP', 48, Decimal('1378.34395')),
#  ('SOUTH YORKSHIRE & BASSETLAW STP', 48, Decimal('1287.77687')),
#  ('MID AND SOUTH ESSEX STP', 48, Decimal('285.57960')),
#  ('MID AND SOUTH ESSEX STP', 48, Decimal('1646.86475')),
#  ('MID AND SOUTH ESSEX STP', 48, Decimal('397.76703')),
#  ('MID AND SOUTH ESSEX STP', 48, Decimal('1444.49455')),
#  ('MID AND SOUTH ESSEX STP', 47, Decimal('2000.54616')),
#  ('MID AND SOUTH ESSEX STP', 47, Decimal('1082.99936')),
#  ('MID AND SOUTH ESSEX STP', 47, Decimal('321.85772')),
#  ('STAFFORDSHIRE & STOKE ON TRENT STP', 47, Decimal('552.01640')),
#  ('MID AND SOUTH ESSEX STP', 47, Decimal('358.67842')),
#  ('NHS SUSSEX INTEGRATED CARE BOARD', 47, Decimal('4082.26579')),
#  ('MID AND SOUTH ESSEX STP', 47, Decimal('1242.38053')),
#  ('CHESHIRE & MERSEYSIDE STP', 47, Decimal('457.22000')),
#  ('CUMBRIA & NORTH EAST STP', 47, Decimal('2187.38396')),
#  ('HUMBER, COAST & VALE STP', 47, Decimal('1322.68314')),
#  ('HUMBER, COAST & VALE STP', 47, Decimal('1051.36640')),
#  ('HUMBER, COAST & VALE STP', 47, Decimal('328.43640')),
#  ('CUMBRIA & NORTH EAST STP', 47, Decimal('761.40519')),
#  ('CHESHIRE & MERSEYSIDE STP', 47, Decimal('683.91517')),
#  ('CHESHIRE & MERSEYSIDE STP', 46, Decimal('289.97106')),
#  ('CHESHIRE & MERSEYSIDE STP', 46, Decimal('206.16388')),
#  ('CHESHIRE & MERSEYSIDE STP', 46, Decimal('830.86397')),
#  ('HUMBER, COAST & VALE STP', 46, Decimal('782.09305')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 46, Decimal('1544.49832')),
#  ('HUMBER, COAST & VALE STP', 46, Decimal('1671.61683')),
#  ('HUMBER, COAST & VALE STP', 46, Decimal('804.71414')),
#  ('HUMBER, COAST & VALE STP', 46, Decimal('778.38500')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 46, Decimal('410.31784')),
#  ('HUMBER, COAST & VALE STP', 46, Decimal('2707.88464')),
#  ('HUMBER, COAST & VALE STP', 46, Decimal('798.25234')),
#  ('HUMBER, COAST & VALE STP', 46, Decimal('2318.21764')),
#  ('SOUTH YORKSHIRE & BASSETLAW STP', 46, Decimal('158.84956')),
#  ('MID AND SOUTH ESSEX STP', 46, Decimal('575.38676')),
#  ('MID AND SOUTH ESSEX STP', 46, Decimal('655.08493')),
#  ('SOUTH YORKSHIRE & BASSETLAW STP', 46, Decimal('2688.48368')),
#  ('MID AND SOUTH ESSEX STP', 46, Decimal('574.68643')),
#  ('MID AND SOUTH ESSEX STP', 46, Decimal('271.97924')),
#  ('MID AND SOUTH ESSEX STP', 46, Decimal('267.36442')),
#  ('MID AND SOUTH ESSEX STP', 46, Decimal('643.62932')),
#  ('MID AND SOUTH ESSEX STP', 46, Decimal('355.14379')),
#  ('MID AND SOUTH ESSEX STP', 45, Decimal('465.59048')),
#  ('MID AND SOUTH ESSEX STP', 45, Decimal('14313.83652')),
#  ('MID AND SOUTH ESSEX STP', 45, Decimal('1284.13384')),
#  ('MID AND SOUTH ESSEX STP', 45, Decimal('510.95915')),
#  ('MID AND SOUTH ESSEX STP', 45, Decimal('708.10301')),
#  ('MID AND SOUTH ESSEX STP', 45, Decimal('450.21756')),
#  ('MID AND SOUTH ESSEX STP', 45, Decimal('199.79812')),
#  ('HUMBER, COAST & VALE STP', 45, Decimal('939.88385')),
#  ('HUMBER, COAST & VALE STP', 45, Decimal('671.52965')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 45, Decimal('834.94740')),
#  ('HUMBER, COAST & VALE STP', 45, Decimal('546.13322')),
#  ('HUMBER, COAST & VALE STP', 45, Decimal('3357.04132')),
#  ('CHESHIRE & MERSEYSIDE STP', 45, Decimal('433.11767')),
#  ('HUMBER, COAST & VALE STP', 45, Decimal('2134.04118')),
#  ('HUMBER, COAST & VALE STP', 45, Decimal('731.40759')),
#  ('HUMBER, COAST & VALE STP', 45, Decimal('709.67727')),
#  ('HUMBER, COAST & VALE STP', 45, Decimal('3415.45560')),
#  ('HUMBER, COAST & VALE STP', 45, Decimal('1343.77835')),
#  ('HAMPSHIRE & THE ISLE OF WIGHT STP', 44, Decimal('509.97819')),
#  ('HAMPSHIRE & THE ISLE OF WIGHT STP', 44, Decimal('1539.93993')),
#  ('CHESHIRE & MERSEYSIDE STP', 44, Decimal('1308.94815')),
#  ('HUMBER, COAST & VALE STP', 44, Decimal('481.55566')),
#  ('HUMBER, COAST & VALE STP', 44, Decimal('931.38238')),
#  ('CHESHIRE & MERSEYSIDE STP', 44, Decimal('1374.61432')),
#  ('HUMBER, COAST & VALE STP', 44, Decimal('711.23764')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 44, Decimal('880.90576')),
#  ('CUMBRIA & NORTH EAST STP', 44, Decimal('1228.68446')),
#  ('HUMBER, COAST & VALE STP', 44, Decimal('218.88600')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 44, Decimal('2837.95699')),
#  ('HUMBER, COAST & VALE STP', 44, Decimal('1730.58940')),
#  ('HUMBER, COAST & VALE STP', 44, Decimal('1993.88601')),
#  ('CHESHIRE & MERSEYSIDE STP', 44, Decimal('951.04607')),
#  ('DEVON STP', 44, Decimal('878.96045')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 44, Decimal('102.95241')),
#  ('HUMBER, COAST & VALE STP', 44, Decimal('658.97378')),
#  ('MID AND SOUTH ESSEX STP', 44, Decimal('267.30685')),
#  ('MID AND SOUTH ESSEX STP', 44, Decimal('491.55790')),
#  ('MID AND SOUTH ESSEX STP', 44, Decimal('997.26560')),
#  ('SUSSEX & EAST SURREY STP', 44, Decimal('1919.23305')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 43, Decimal('1869.37416')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 43, Decimal('308.74198')),
#  ('HUMBER, COAST & VALE STP', 43, Decimal('210.71523')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 43, Decimal('1492.64643')),
#  ('HUMBER, COAST & VALE STP', 43, Decimal('776.92019')),
#  ('HUMBER, COAST & VALE STP', 43, Decimal('2823.41068')),
#  ('CHESHIRE & MERSEYSIDE STP', 43, Decimal('1166.81846')),
#  ('CHESHIRE & MERSEYSIDE STP', 43, Decimal('2425.18436')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 43, Decimal('274.59738')),
#  ('CHESHIRE & MERSEYSIDE STP', 43, Decimal('740.67398')),
#  ('MID AND SOUTH ESSEX STP', 43, Decimal('1045.89517')),
#  ('MID AND SOUTH ESSEX STP', 43, Decimal('526.35619')),
#  ('MID AND SOUTH ESSEX STP', 43, Decimal('609.26571')),
#  ('MID AND SOUTH ESSEX STP', 43, Decimal('1386.65310')),
#  ('MID AND SOUTH ESSEX STP', 43, Decimal('4856.25978')),
#  ('MID AND SOUTH ESSEX STP', 43, Decimal('46786.34308')),
#  ('MID AND SOUTH ESSEX STP', 43, Decimal('1294.76431')),
#  ('MID AND SOUTH ESSEX STP', 43, Decimal('2592.47786')),
#  ('SOUTH YORKSHIRE & BASSETLAW STP', 43, Decimal('1161.94431')),
#  ('MID AND SOUTH ESSEX STP', 43, Decimal('540.14900')),
#  ('MID AND SOUTH ESSEX STP', 43, Decimal('1622.09379')),
#  ('SOUTH YORKSHIRE & BASSETLAW STP', 42, Decimal('253.13709')),
#  ('MID AND SOUTH ESSEX STP', 42, Decimal('644.61378')),
#  ('MID AND SOUTH ESSEX STP', 42, Decimal('298.75246')),
#  ('MID AND SOUTH ESSEX STP', 42, Decimal('860.42072')),
#  ('MID AND SOUTH ESSEX STP', 42, Decimal('1511.14895')),
#  ('CHESHIRE & MERSEYSIDE STP', 42, Decimal('441.22738')),
#  ('HUMBER, COAST & VALE STP', 42, Decimal('471.77120')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 42, Decimal('138.15699')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 42, Decimal('2057.43600')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 42, Decimal('240.61278')),
#  ('CHESHIRE & MERSEYSIDE STP', 42, Decimal('654.28451')),
#  ('HUMBER, COAST & VALE STP', 42, Decimal('1348.05535')),
#  ('HUMBER, COAST & VALE STP', 42, Decimal('1732.45588')),
#  ('HUMBER, COAST & VALE STP', 42, Decimal('1382.22612')),
#  ('HUMBER, COAST & VALE STP', 41, Decimal('4795.24515')),
#  ('HUMBER, COAST & VALE STP', 41, Decimal('798.23744')),
#  ('HUMBER, COAST & VALE STP', 41, Decimal('12285.49292')),
#  ('HUMBER, COAST & VALE STP', 41, Decimal('780.32508')),
#  ('CHESHIRE & MERSEYSIDE STP', 41, Decimal('380.78124')),
#  ('HUMBER, COAST & VALE STP', 41, Decimal('616.19147')),
#  ('CHESHIRE & MERSEYSIDE STP', 41, Decimal('736.88368')),
#  ('HUMBER, COAST & VALE STP', 41, Decimal('2363.16433')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 41, Decimal('812.81440')),
#  ('HAMPSHIRE & THE ISLE OF WIGHT STP', 41, Decimal('530.34518')),
#  ('CHESHIRE & MERSEYSIDE STP', 41, Decimal('287.86999')),
#  ('MID AND SOUTH ESSEX STP', 41, Decimal('1246.07503')),
#  ('MID AND SOUTH ESSEX STP', 41, Decimal('1842.56027')),
#  ('MID AND SOUTH ESSEX STP', 41, Decimal('898.30120')),
#  ('MID AND SOUTH ESSEX STP', 41, Decimal('1192.59127')),
#  ('STAFFORDSHIRE & STOKE ON TRENT STP', 41, Decimal('2162.07232')),
#  ('STAFFORDSHIRE & STOKE ON TRENT STP', 40, Decimal('1492.12643')),
#  ('STAFFORDSHIRE & STOKE ON TRENT STP', 40, Decimal('111.93509')),
#  ('MID AND SOUTH ESSEX STP', 40, Decimal('375.04983')),
#  ('STAFFORDSHIRE & STOKE ON TRENT STP', 40, Decimal('2258.73813')),
#  ('MID AND SOUTH ESSEX STP', 40, Decimal('462.73071')),
#  ('MID AND SOUTH ESSEX STP', 40, Decimal('873.69870')),
#  ('MID AND SOUTH ESSEX STP', 40, Decimal('1235.01575')),
#  ('MID AND SOUTH ESSEX STP', 40, Decimal('392.37267')),
#  ('CHESHIRE & MERSEYSIDE STP', 40, Decimal('1075.77466')),
#  ('CHESHIRE & MERSEYSIDE STP', 40, Decimal('765.92313')),
#  ('HUMBER, COAST & VALE STP', 40, Decimal('1566.40301')),
#  ('HUMBER, COAST & VALE STP', 40, Decimal('1246.36343')),
#  ('HUMBER, COAST & VALE STP', 40, Decimal('1060.14653')),
#  ('CHESHIRE & MERSEYSIDE STP', 40, Decimal('600.31503')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 40, Decimal('371.33154')),
#  ('CHESHIRE & MERSEYSIDE STP', 40, Decimal('1948.07423')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 40, Decimal('635.67214')),
#  ('HUMBER, COAST & VALE STP', 40, Decimal('2672.65056')),
#  ('CHESHIRE & MERSEYSIDE STP', 40, Decimal('1710.19333')),
#  ('CUMBRIA & NORTH EAST STP', 40, Decimal('402.76357')),
#  ('HUMBER, COAST & VALE STP', 40, Decimal('519.08769')),
#  ('HUMBER, COAST & VALE STP', 40, Decimal('148.34524')),
#  ('HUMBER, COAST & VALE STP', 40, Decimal('419.34572')),
#  ('HAMPSHIRE & THE ISLE OF WIGHT STP', 40, Decimal('1544.57866')),
#  ('CHESHIRE & MERSEYSIDE STP', 40, Decimal('596.11034')),
#  ('HUMBER, COAST & VALE STP', 39, Decimal('691.20473')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 39, Decimal('585.09292')),
#  ('HUMBER, COAST & VALE STP', 39, Decimal('1475.89761')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 39, Decimal('1536.84780')),
#  ('HUMBER, COAST & VALE STP', 39, Decimal('566.58665')),
#  ('HUMBER, COAST & VALE STP', 39, Decimal('417.71159')),
#  ('CHESHIRE & MERSEYSIDE STP', 39, Decimal('833.43133')),
#  ('CHESHIRE & MERSEYSIDE STP', 39, Decimal('530.47170')),
#  ('CUMBRIA & NORTH EAST STP', 39, Decimal('670.59454')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 39, Decimal('720.85928')),
#  ('HUMBER, COAST & VALE STP', 39, Decimal('1183.63652')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 39, Decimal('121.39784')),
#  ('CHESHIRE & MERSEYSIDE STP', 39, Decimal('1367.28080')),
#  ('STAFFORDSHIRE & STOKE ON TRENT STP', 39, Decimal('463.54860')),
#  ('MID AND SOUTH ESSEX STP', 39, Decimal('904.10783')),
#  ('MID AND SOUTH ESSEX STP', 39, Decimal('584.47544')),
#  ('MID AND SOUTH ESSEX STP', 39, Decimal('289.17045')),
#  ('MID AND SOUTH ESSEX STP', 39, Decimal('1337.84708')),
#  ('MID AND SOUTH ESSEX STP', 38, Decimal('1455.24347')),
#  ('MID AND SOUTH ESSEX STP', 38, Decimal('428.77791')),
#  ('MID AND SOUTH ESSEX STP', 38, Decimal('500.02145')),
#  ('MID AND SOUTH ESSEX STP', 38, Decimal('118.46653')),
#  ('MID AND SOUTH ESSEX STP', 38, Decimal('1206.66390')),
#  ('MID AND SOUTH ESSEX STP', 38, Decimal('424.71106')),
#  ('MID AND SOUTH ESSEX STP', 38, Decimal('464.85248')),
#  ('MID AND SOUTH ESSEX STP', 38, Decimal('2121.46806')),
#  ('STAFFORDSHIRE & STOKE ON TRENT STP', 38, Decimal('258.55941')),
#  ('HUMBER, COAST & VALE STP', 38, Decimal('330.75882')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 38, Decimal('1160.18907')),
#  ('HUMBER, COAST & VALE STP', 38, Decimal('572.55139')),
#  ('CHESHIRE & MERSEYSIDE STP', 38, Decimal('840.62681')),
#  ('CUMBRIA & NORTH EAST STP', 38, Decimal('223.58961')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 38, Decimal('117.79319')),
#  ('CHESHIRE & MERSEYSIDE STP', 38, Decimal('378.32937')),
#  ('HUMBER, COAST & VALE STP', 38, Decimal('2737.18606')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 38, Decimal('685.25854')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 38, Decimal('1064.66303')),
#  ('CHESHIRE & MERSEYSIDE STP', 38, Decimal('550.89872')),
#  ('CHESHIRE & MERSEYSIDE STP', 38, Decimal('924.23076')),
#  ('HUMBER, COAST & VALE STP', 38, Decimal('406.18666')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 38, Decimal('728.70549')),
#  ('HAMPSHIRE & THE ISLE OF WIGHT STP', 38, Decimal('278.54819')),
#  ('CHESHIRE & MERSEYSIDE STP', 37, Decimal('279.15479')),
#  ('HUMBER, COAST & VALE STP', 37, Decimal('38600.18811')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 37, Decimal('1802.59973')),
#  ('CHESHIRE & MERSEYSIDE STP', 37, Decimal('1077.16999')),
#  ('HUMBER, COAST & VALE STP', 37, Decimal('149.88242')),
#  ('CHESHIRE & MERSEYSIDE STP', 37, Decimal('300.50561')),
#  ('HUMBER, COAST & VALE STP', 37, Decimal('467.22900')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 37, Decimal('1862.54711')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 37, Decimal('3670.18912')),
#  ('HUMBER, COAST & VALE STP', 37, Decimal('976.95342')),
#  ('HUMBER, COAST & VALE STP', 37, Decimal('984.69912')),
#  ('HAMPSHIRE & THE ISLE OF WIGHT STP', 37, Decimal('349.91483')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 37, Decimal('238.05355')),
#  ('HUMBER, COAST & VALE STP', 37, Decimal('735.53939')),
#  ('HUMBER, COAST & VALE STP', 37, Decimal('331.54803')),
#  ('CHESHIRE & MERSEYSIDE STP', 37, Decimal('680.45813')),
#  ('CHESHIRE & MERSEYSIDE STP', 37, Decimal('648.42933')),
#  ('HAMPSHIRE & THE ISLE OF WIGHT STP', 37, Decimal('751.37063')),
#  ('HUMBER, COAST & VALE STP', 37, Decimal('443.20273')),
#  ('HUMBER, COAST & VALE STP', 37, Decimal('58380.56360')),
#  ('MID AND SOUTH ESSEX STP', 37, Decimal('456.37873')),
#  ('MID AND SOUTH ESSEX STP', 37, Decimal('764.16047')),
#  ('MID AND SOUTH ESSEX STP', 37, Decimal('274.96301')),
#  ('MID AND SOUTH ESSEX STP', 37, Decimal('399.78700')),
#  ('MID AND SOUTH ESSEX STP', 37, Decimal('1938.26972')),
#  ('MID AND SOUTH ESSEX STP', 37, Decimal('3279.12542')),
#  ('MID AND SOUTH ESSEX STP', 37, Decimal('10763.60572')),
#  ('MID AND SOUTH ESSEX STP', 37, Decimal('283.57463')),
#  ('STAFFORDSHIRE & STOKE ON TRENT STP', 37, Decimal('338.70511')),
#  ('MID AND SOUTH ESSEX STP', 37, Decimal('481.07210')),
#  ('SOUTH YORKSHIRE & BASSETLAW STP', 37, Decimal('461.89459')),
#  ('MID AND SOUTH ESSEX STP', 36, Decimal('466.77441')),
#  ('MID AND SOUTH ESSEX STP', 36, Decimal('231.23907')),
#  ('MID AND SOUTH ESSEX STP', 36, Decimal('1993.16854')),
#  ('MID AND SOUTH ESSEX STP', 36, Decimal('647.77916')),
#  ('MID AND SOUTH ESSEX STP', 36, Decimal('330.23505')),
#  ('MID AND SOUTH ESSEX STP', 36, Decimal('593.67581')),
#  ('MID AND SOUTH ESSEX STP', 36, Decimal('458.86165')),
#  ('MID AND SOUTH ESSEX STP', 36, Decimal('8651.03228')),
#  ('HUMBER, COAST & VALE STP', 36, Decimal('368.47567')),
#  ('HAMPSHIRE & THE ISLE OF WIGHT STP', 36, Decimal('543.10292')),
#  ('HUMBER, COAST & VALE STP', 36, Decimal('1108.96771')),
#  ('HUMBER, COAST & VALE STP', 36, Decimal('843.83806')),
#  ('CHESHIRE & MERSEYSIDE STP', 36, Decimal('542.44118')),
#  ('HUMBER, COAST & VALE STP', 36, Decimal('162.48659')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 36, Decimal('539.78925')),
#  ('HUMBER, COAST & VALE STP', 36, Decimal('944.92094')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 36, Decimal('855.79333')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 36, Decimal('2753.32814')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 36, Decimal('1343.33323')),
#  ('CHESHIRE & MERSEYSIDE STP', 36, Decimal('4885.95447')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 36, Decimal('239.55615')),
#  ('HUMBER, COAST & VALE STP', 36, Decimal('2341.43348')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 36, Decimal('2350.79053')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 36, Decimal('550.73537')),
#  ('HUMBER, COAST & VALE STP', 35, Decimal('267.89514')),
#  ('HUMBER, COAST & VALE STP', 35, Decimal('277.37870')),
#  ('HUMBER, COAST & VALE STP', 35, Decimal('1940.64493')),
#  ('HUMBER, COAST & VALE STP', 35, Decimal('372.88095')),
#  ('HUMBER, COAST & VALE STP', 35, Decimal('459.05530')),
#  ('HUMBER, COAST & VALE STP', 35, Decimal('582.07440')),
#  ('CHESHIRE & MERSEYSIDE STP', 35, Decimal('819.11677')),
#  ('HUMBER, COAST & VALE STP', 35, Decimal('1396.25611')),
#  ('HUMBER, COAST & VALE STP', 35, Decimal('9517.57369')),
#  ('CHESHIRE & MERSEYSIDE STP', 35, Decimal('1766.88247')),
#  ('HUMBER, COAST & VALE STP', 35, Decimal('775.24833')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 35, Decimal('389.00331')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 35, Decimal('1017.13665')),
#  ('HUMBER, COAST & VALE STP', 35, Decimal('477.62054')),
#  ('HUMBER, COAST & VALE STP', 35, Decimal('1074.51294')),
#  ('HUMBER, COAST & VALE STP', 35, Decimal('1267.09076')),
#  ('HAMPSHIRE & THE ISLE OF WIGHT STP', 35, Decimal('5737.04684')),
#  ('HUMBER, COAST & VALE STP', 35, Decimal('138.78820')),
#  ('HUMBER, COAST & VALE STP', 35, Decimal('626.89566')),
#  ('HUMBER, COAST & VALE STP', 35, Decimal('1103.74908')),
#  ('HUMBER, COAST & VALE STP', 35, Decimal('1006.91341')),
#  ('HUMBER, COAST & VALE STP', 35, Decimal('458.47573')),
#  ('CHESHIRE & MERSEYSIDE STP', 35, Decimal('301.96605')),
#  ('SOUTH YORKSHIRE & BASSETLAW STP', 35, Decimal('770.86706')),
#  ('MID AND SOUTH ESSEX STP', 35, Decimal('319.26892')),
#  ('MID AND SOUTH ESSEX STP', 35, Decimal('628.82888')),
#  ('MID AND SOUTH ESSEX STP', 35, Decimal('1089.62365')),
#  ('MID AND SOUTH ESSEX STP', 35, Decimal('869.43049')),
#  ('MID AND SOUTH ESSEX STP', 35, Decimal('1221.27938')),
#  ('MID AND SOUTH ESSEX STP', 35, Decimal('2290.89965')),
#  ('MID AND SOUTH ESSEX STP', 35, Decimal('653.69596')),
#  ('UNIDENTIFIED', 35, Decimal('853.50931')),
#  ('STAFFORDSHIRE & STOKE ON TRENT STP', 34, Decimal('325.43144')),
#  ('HUMBER, COAST & VALE STP', 34, Decimal('1750.62534')),
#  ('CHESHIRE & MERSEYSIDE STP', 34, Decimal('616.80376')),
#  ('HAMPSHIRE & THE ISLE OF WIGHT STP', 34, Decimal('1043.30462')),
#  ('CHESHIRE & MERSEYSIDE STP', 34, Decimal('1518.09853')),
#  ('HUMBER, COAST & VALE STP', 34, Decimal('2571.94355')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 34, Decimal('734.34746')),
#  ('HUMBER, COAST & VALE STP', 34, Decimal('103.91041')),
#  ('HUMBER, COAST & VALE STP', 34, Decimal('1003.12249')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 34, Decimal('340.53696')),
#  ('HUMBER, COAST & VALE STP', 34, Decimal('479.68744')),
#  ('CUMBRIA & NORTH EAST STP', 34, Decimal('565.24139')),
#  ('CHESHIRE & MERSEYSIDE STP', 34, Decimal('2510.76184')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 34, Decimal('487.35654')),
#  ('HUMBER, COAST & VALE STP', 34, Decimal('98.78528')),
#  ('HUMBER, COAST & VALE STP', 34, Decimal('501.83408')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 34, Decimal('309.32660')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 34, Decimal('196.22519')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 34, Decimal('839.71233')),
#  ('HUMBER, COAST & VALE STP', 34, Decimal('596.55556')),
#  ('HUMBER, COAST & VALE STP', 34, Decimal('1332.87294')),
#  ('HUMBER, COAST & VALE STP', 34, Decimal('114.87282')),
#  ('STAFFORDSHIRE & STOKE ON TRENT STP', 34, Decimal('436.55154')),
#  ('SOUTH YORKSHIRE & BASSETLAW STP', 34, Decimal('924.29391')),
#  ('MID AND SOUTH ESSEX STP', 34, Decimal('22208.55801')),
#  ('MID AND SOUTH ESSEX STP', 34, Decimal('158.74388')),
#  ('MID AND SOUTH ESSEX STP', 34, Decimal('148.45412')),
#  ('MID AND SOUTH ESSEX STP', 34, Decimal('841.39620')),
#  ('MID AND SOUTH ESSEX STP', 34, Decimal('440.95807')),
#  ('MID AND SOUTH ESSEX STP', 34, Decimal('383.17807')),
#  ('MID AND SOUTH ESSEX STP', 34, Decimal('177.07206')),
#  ('MID AND SOUTH ESSEX STP', 34, Decimal('934.88993')),
#  ('MID AND SOUTH ESSEX STP', 34, Decimal('336.44457')),
#  ('MID AND SOUTH ESSEX STP', 33, Decimal('428.82144')),
#  ('MID AND SOUTH ESSEX STP', 33, Decimal('444.95999')),
#  ('MID AND SOUTH ESSEX STP', 33, Decimal('617.14635')),
#  ('MID AND SOUTH ESSEX STP', 33, Decimal('3633.32230')),
#  ('MID AND SOUTH ESSEX STP', 33, Decimal('223.32137')),
#  ('MID AND SOUTH ESSEX STP', 33, Decimal('6497.51078')),
#  ('NHS HUMBER AND NORTH YORKSHIRE INTEGRATE', 33, Decimal('413.83021')),
#  ('MID AND SOUTH ESSEX STP', 33, Decimal('805.10074')),
#  ('MID AND SOUTH ESSEX STP', 33, Decimal('189.98433')),
#  ('MID AND SOUTH ESSEX STP', 33, Decimal('5403.26483')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 33, Decimal('1453.38097')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 33, Decimal('748.04324')),
#  ('HUMBER, COAST & VALE STP', 33, Decimal('1107.25629')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 33, Decimal('665.80806')),
#  ('HAMPSHIRE & THE ISLE OF WIGHT STP', 33, Decimal('197.69227')),
#  ('HUMBER, COAST & VALE STP', 33, Decimal('562.71230')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 33, Decimal('753.17845')),
#  ('HUMBER, COAST & VALE STP', 33, Decimal('952.37227')),
#  ('HUMBER, COAST & VALE STP', 33, Decimal('887.64408')),
#  ('HUMBER, COAST & VALE STP', 33, Decimal('1155.71013')),
#  ('HUMBER, COAST & VALE STP', 33, Decimal('4749.03439')),
#  ('HUMBER, COAST & VALE STP', 33, Decimal('2294.71453')),
#  ('HUMBER, COAST & VALE STP', 33, Decimal('1026.88478')),
#  ('HUMBER, COAST & VALE STP', 33, Decimal('443.81768')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 33, Decimal('890.22783')),
#  ('HUMBER, COAST & VALE STP', 33, Decimal('1895.76952')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 33, Decimal('1069.30595')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 33, Decimal('399.01142')),
#  ('HUMBER, COAST & VALE STP', 33, Decimal('630.92606')),
#  ('HUMBER, COAST & VALE STP', 33, Decimal('669.26375')),
#  ('HUMBER, COAST & VALE STP', 33, Decimal('201.60562')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 33, Decimal('365.57422')),
#  ('HUMBER, COAST & VALE STP', 33, Decimal('638.61898')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 33, Decimal('2112.31276')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 33, Decimal('1198.28313')),
#  ('HAMPSHIRE & THE ISLE OF WIGHT STP', 33, Decimal('234.70698')),
#  ('HUMBER, COAST & VALE STP', 33, Decimal('1559.09367')),
#  ('HUMBER, COAST & VALE STP', 33, Decimal('468.73461')),
#  ('HUMBER, COAST & VALE STP', 33, Decimal('9181.94486')),
#  ('CHESHIRE & MERSEYSIDE STP', 33, Decimal('734.70647')),
#  ('HUMBER, COAST & VALE STP', 33, Decimal('1122.07437')),
#  ('CHESHIRE & MERSEYSIDE STP', 33, Decimal('445.82385')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 33, Decimal('4396.08720')),
#  ('HUMBER, COAST & VALE STP', 33, Decimal('311.25129')),
#  ('CHESHIRE & MERSEYSIDE STP', 33, Decimal('1418.62736')),
#  ('HUMBER, COAST & VALE STP', 33, Decimal('2052.00567')),
#  ('HUMBER, COAST & VALE STP', 33, Decimal('386.53353')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 33, Decimal('252.19210')),
#  ('HUMBER, COAST & VALE STP', 33, Decimal('294.59478')),
#  ('HUMBER, COAST & VALE STP', 33, Decimal('190.79956')),
#  ('HUMBER, COAST & VALE STP', 33, Decimal('1741.72921')),
#  ('HUMBER, COAST & VALE STP', 32, Decimal('2815.19922')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 32, Decimal('355.68455')),
#  ('HUMBER, COAST & VALE STP', 32, Decimal('1798.57168')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 32, Decimal('726.98000')),
#  ('HUMBER, COAST & VALE STP', 32, Decimal('343.14727')),
#  ('HUMBER, COAST & VALE STP', 32, Decimal('449.22073')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 32, Decimal('1893.38468')),
#  ('HUMBER, COAST & VALE STP', 32, Decimal('361.46408')),
#  ('HUMBER, COAST & VALE STP', 32, Decimal('1194.21634')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 32, Decimal('460.47697')),
#  ('HUMBER, COAST & VALE STP', 32, Decimal('523.76953')),
#  ('CHESHIRE & MERSEYSIDE STP', 32, Decimal('858.41230')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 32, Decimal('763.87365')),
#  ('CHESHIRE & MERSEYSIDE STP', 32, Decimal('423.84075')),
#  ('HUMBER, COAST & VALE STP', 32, Decimal('289.81931')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 32, Decimal('622.84576')),
#  ('CHESHIRE & MERSEYSIDE STP', 32, Decimal('463.23926')),
#  ('HUMBER, COAST & VALE STP', 32, Decimal('1295.52518')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 32, Decimal('139.90389')),
#  ('HUMBER, COAST & VALE STP', 32, Decimal('988.14251')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 32, Decimal('70.24695')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 32, Decimal('570.23914')),
#  ('HUMBER, COAST & VALE STP', 32, Decimal('822.64740')),
#  ('MID AND SOUTH ESSEX STP', 32, Decimal('588.30861')),
#  ('MID AND SOUTH ESSEX STP', 32, Decimal('3234.46460')),
#  ('MID AND SOUTH ESSEX STP', 32, Decimal('1469.91627')),
#  ('MID AND SOUTH ESSEX STP', 32, Decimal('415.44260')),
#  ('MID AND SOUTH ESSEX STP', 32, Decimal('209.98681')),
#  ('MID AND SOUTH ESSEX STP', 32, Decimal('268.21818')),
#  ('MID AND SOUTH ESSEX STP', 32, Decimal('458.51906')),
#  ('MID AND SOUTH ESSEX STP', 32, Decimal('962.92028')),
#  ('MID AND SOUTH ESSEX STP', 32, Decimal('1224.68593')),
#  ('MID AND SOUTH ESSEX STP', 32, Decimal('572.62334')),
#  ('MID AND SOUTH ESSEX STP', 32, Decimal('485.10107')),
#  ('MID AND SOUTH ESSEX STP', 32, Decimal('487.76879')),
#  ('MID AND SOUTH ESSEX STP', 32, Decimal('263.33652')),
#  ('MID AND SOUTH ESSEX STP', 32, Decimal('650.11276')),
#  ('MID AND SOUTH ESSEX STP', 32, Decimal('129.80070')),
#  ('MID AND SOUTH ESSEX STP', 32, Decimal('8591.14754')),
#  ('STAFFORDSHIRE & STOKE ON TRENT STP', 32, Decimal('381.63547')),
#  ('SOUTH YORKSHIRE & BASSETLAW STP', 32, Decimal('202.37428')),
#  ('MID AND SOUTH ESSEX STP', 31, Decimal('239.52940')),
#  ('MID AND SOUTH ESSEX STP', 31, Decimal('299.90135')),
#  ('MID AND SOUTH ESSEX STP', 31, Decimal('597.74634')),
#  ('STAFFORDSHIRE & STOKE ON TRENT STP', 31, Decimal('995.23460')),
#  ('SOUTH YORKSHIRE & BASSETLAW STP', 31, Decimal('129.73026')),
#  ('MID AND SOUTH ESSEX STP', 31, Decimal('20178.03453')),
#  ('NHS CHESHIRE AND MERSEYSIDE INTEGRATED C', 31, Decimal('167.29380')),
#  ('MID AND SOUTH ESSEX STP', 31, Decimal('177.72724')),
#  ('SOUTH YORKSHIRE & BASSETLAW STP', 31, Decimal('656.76174')),
#  ('SOUTH YORKSHIRE & BASSETLAW STP', 31, Decimal('1255.80329')),
#  ('SOUTH YORKSHIRE & BASSETLAW STP', 31, Decimal('468.36602')),
#  ('MID AND SOUTH ESSEX STP', 31, Decimal('129.63521')),
#  ('MID AND SOUTH ESSEX STP', 31, Decimal('211.82035')),
#  ('SOUTH YORKSHIRE & BASSETLAW STP', 31, Decimal('1629.23342')),
#  ('MID AND SOUTH ESSEX STP', 31, Decimal('4899.18310')),
#  ('MID AND SOUTH ESSEX STP', 31, Decimal('719.37904')),
#  ('MID AND SOUTH ESSEX STP', 31, Decimal('183.27894')),
#  ('SOUTH YORKSHIRE & BASSETLAW STP', 31, Decimal('802.39804')),
#  ('MID AND SOUTH ESSEX STP', 31, Decimal('765.04778')),
#  ('MID AND SOUTH ESSEX STP', 31, Decimal('366.16283')),
#  ('MID AND SOUTH ESSEX STP', 31, Decimal('276.56977')),
#  ('MID AND SOUTH ESSEX STP', 31, Decimal('483.71809')),
#  ('SUSSEX & EAST SURREY STP', 31, Decimal('26952.70009')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 31, Decimal('817.27849')),
#  ('HUMBER, COAST & VALE STP', 31, Decimal('747.78808')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 31, Decimal('778.83050')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 31, Decimal('485.26190')),
#  ('HAMPSHIRE & THE ISLE OF WIGHT STP', 31, Decimal('1258.46256')),
#  ('HUMBER, COAST & VALE STP', 31, Decimal('656.87290')),
#  ('HUMBER, COAST & VALE STP', 31, Decimal('1400.98997')),
#  ('HUMBER, COAST & VALE STP', 31, Decimal('641.04652')),
#  ('HUMBER, COAST & VALE STP', 31, Decimal('232.18438')),
#  ('CHESHIRE & MERSEYSIDE STP', 31, Decimal('2259.52158')),
#  ('HUMBER, COAST & VALE STP', 31, Decimal('1437.89964')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 31, Decimal('1550.59560')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 31, Decimal('258.09267')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 31, Decimal('205.39159')),
#  ('HUMBER, COAST & VALE STP', 31, Decimal('816.20892')),
#  ('HUMBER, COAST & VALE STP', 31, Decimal('487.67571')),
#  ('HUMBER, COAST & VALE STP', 31, Decimal('1035.41066')),
#  ('HUMBER, COAST & VALE STP', 31, Decimal('881.86206')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 31, Decimal('1531.62884')),
#  ('HUMBER, COAST & VALE STP', 31, Decimal('482.77455')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 31, Decimal('565.19932')),
#  ('HUMBER, COAST & VALE STP', 31, Decimal('30832.91020')),
#  ('HUMBER, COAST & VALE STP', 31, Decimal('431.06466')),
#  ('HUMBER, COAST & VALE STP', 31, Decimal('281.44781')),
#  ('HUMBER, COAST & VALE STP', 31, Decimal('1654.40597')),
#  ('CHESHIRE & MERSEYSIDE STP', 31, Decimal('438.19692')),
#  ('HUMBER, COAST & VALE STP', 31, Decimal('7910.45428')),
#  ('HUMBER, COAST & VALE STP', 31, Decimal('194.20063')),
#  ('CHESHIRE & MERSEYSIDE STP', 31, Decimal('1061.63150')),
#  ('HUMBER, COAST & VALE STP', 31, Decimal('305.65902')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 31, Decimal('635.27788')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 30, Decimal('469.87727')),
#  ('HUMBER, COAST & VALE STP', 30, Decimal('307.73504')),
#  ('CUMBRIA & NORTH EAST STP', 30, Decimal('557.86902')),
#  ('HUMBER, COAST & VALE STP', 30, Decimal('474.21280')),
#  ('HUMBER, COAST & VALE STP', 30, Decimal('709.90845')),
#  ('CHESHIRE & MERSEYSIDE STP', 30, Decimal('411.55285')),
#  ('CUMBRIA & NORTH EAST STP', 30, Decimal('920.90812')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 30, Decimal('866.45874')),
#  ('CUMBRIA & NORTH EAST STP', 30, Decimal('838.65532')),
#  ('HUMBER, COAST & VALE STP', 30, Decimal('363.83104')),
#  ('HUMBER, COAST & VALE STP', 30, Decimal('384.05153')),
#  ('HUMBER, COAST & VALE STP', 30, Decimal('458.02121')),
#  ('HUMBER, COAST & VALE STP', 30, Decimal('651.05017')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 30, Decimal('457.19002')),
#  ('HUMBER, COAST & VALE STP', 30, Decimal('835.58086')),
#  ('HUMBER, COAST & VALE STP', 30, Decimal('942.41121')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 30, Decimal('1820.55476')),
#  ('CHESHIRE & MERSEYSIDE STP', 30, Decimal('423.11099')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 30, Decimal('195.93355')),
#  ('HUMBER, COAST & VALE STP', 30, Decimal('133.33844')),
#  ('EAST LONDON HEALTH & CARE P/SHIP STP', 30, Decimal('1010.36449')),
#  ('HUMBER, COAST & VALE STP', 30, Decimal('2555.03394')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 30, Decimal('534.09949')),
#  ('CHESHIRE & MERSEYSIDE STP', 30, Decimal('3828.90641')),
#  ('HAMPSHIRE & THE ISLE OF WIGHT STP', 30, Decimal('4226.78994')),
#  ('CUMBRIA & NORTH EAST STP', 30, Decimal('320.49289')),
#  ('CHESHIRE & MERSEYSIDE STP', 30, Decimal('1770.91745')),
#  ('HUMBER, COAST & VALE STP', 30, Decimal('329.43580')),
#  ('HUMBER, COAST & VALE STP', 30, Decimal('2601.43662')),
#  ('HUMBER, COAST & VALE STP', 30, Decimal('404.98358')),
#  ('MID AND SOUTH ESSEX STP', 30, Decimal('228.82369')),
#  ('MID AND SOUTH ESSEX STP', 30, Decimal('184.29505')),
#  ('MID AND SOUTH ESSEX STP', 30, Decimal('304.43952')),
#  ('MID AND SOUTH ESSEX STP', 30, Decimal('881.20277')),
#  ('STAFFORDSHIRE & STOKE ON TRENT STP', 30, Decimal('709.95225')),
#  ('MID AND SOUTH ESSEX STP', 30, Decimal('2044.26878')),
#  ('MID AND SOUTH ESSEX STP', 30, Decimal('144.89930')),
#  ('MID AND SOUTH ESSEX STP', 30, Decimal('438.49403')),
#  ('NHS GREATER MANCHESTER INTEGRATED CARE B', 30, Decimal('117.09740')),
#  ('SOUTH YORKSHIRE & BASSETLAW STP', 30, Decimal('311.99048')),
#  ('MID AND SOUTH ESSEX STP', 30, Decimal('86.85818')),
#  ('SOUTH YORKSHIRE & BASSETLAW STP', 30, Decimal('924.93040')),
#  ('MID AND SOUTH ESSEX STP', 30, Decimal('143.02050')),
#  ('STAFFORDSHIRE & STOKE ON TRENT STP', 30, Decimal('1395.33248')),
#  ('STAFFORDSHIRE & STOKE ON TRENT STP', 30, Decimal('2408.65495')),
#  ('CHESHIRE & MERSEYSIDE STP', 29, Decimal('1065.91491')),
#  ('HUMBER, COAST & VALE STP', 29, Decimal('178.30815')),
#  ('HUMBER, COAST & VALE STP', 29, Decimal('189.31109')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 29, Decimal('1356.47735')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 29, Decimal('110.08357')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 29, Decimal('313.68131')),
#  ('HUMBER, COAST & VALE STP', 29, Decimal('1297.19594')),
#  ('CHESHIRE & MERSEYSIDE STP', 29, Decimal('613.57816')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 29, Decimal('2443.98276')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 29, Decimal('654.71020')),
#  ('HUMBER, COAST & VALE STP', 29, Decimal('1265.64057')),
#  ('HUMBER, COAST & VALE STP', 29, Decimal('9996.85876')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 29, Decimal('1233.40571')),
#  ('HUMBER, COAST & VALE STP', 29, Decimal('501.20747')),
#  ('HUMBER, COAST & VALE STP', 29, Decimal('212.12369')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 29, Decimal('1918.09169')),
#  ('HUMBER, COAST & VALE STP', 29, Decimal('339.44643')),
#  ('HUMBER, COAST & VALE STP', 29, Decimal('152.59463')),
#  ('HUMBER, COAST & VALE STP', 29, Decimal('1139.55985')),
#  ('HUMBER, COAST & VALE STP', 29, Decimal('735.01038')),
#  ('CHESHIRE & MERSEYSIDE STP', 29, Decimal('1683.64750')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 29, Decimal('658.20681')),
#  ('HUMBER, COAST & VALE STP', 29, Decimal('254.84127')),
#  ('CUMBRIA & NORTH EAST STP', 29, Decimal('1429.49624')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 29, Decimal('457.52954')),
#  ('HAMPSHIRE & THE ISLE OF WIGHT STP', 29, Decimal('233.17635')),
#  ('HUMBER, COAST & VALE STP', 29, Decimal('156.87709')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 29, Decimal('423.14830')),
#  ('HUMBER, COAST & VALE STP', 29, Decimal('854.83026')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 29, Decimal('313.81227')),
#  ('CHESHIRE & MERSEYSIDE STP', 29, Decimal('744.51786')),
#  ('HUMBER, COAST & VALE STP', 29, Decimal('433.67996')),
#  ('HAMPSHIRE & THE ISLE OF WIGHT STP', 29, Decimal('929.32163')),
#  ('HUMBER, COAST & VALE STP', 29, Decimal('142.91761')),
#  ('MID AND SOUTH ESSEX STP', 29, Decimal('146.32158')),
#  ('MID AND SOUTH ESSEX STP', 29, Decimal('284.36917')),
#  ('MID AND SOUTH ESSEX STP', 29, Decimal('824.68249')),
#  ('NORTH LONDON PARTNERS IN H&C STP', 29, Decimal('1053.60471')),
#  ('SOUTH YORKSHIRE & BASSETLAW STP', 29, Decimal('1488.08054')),
#  ('MID AND SOUTH ESSEX STP', 29, Decimal('137.99740')),
#  ('MID AND SOUTH ESSEX STP', 29, Decimal('202.58159')),
#  ('MID AND SOUTH ESSEX STP', 29, Decimal('494.34289')),
#  ('MID AND SOUTH ESSEX STP', 29, Decimal('270.10875')),
#  ('MID AND SOUTH ESSEX STP', 29, Decimal('5483.15969')),
#  ('MID AND SOUTH ESSEX STP', 29, Decimal('112.82206')),
#  ('MID AND SOUTH ESSEX STP', 29, Decimal('6937.95099')),
#  ('MID AND SOUTH ESSEX STP', 29, Decimal('602.07297')),
#  ('STAFFORDSHIRE & STOKE ON TRENT STP', 29, Decimal('647.00549')),
#  ('SOUTH YORKSHIRE & BASSETLAW STP', 29, Decimal('943.97547')),
#  ('MID AND SOUTH ESSEX STP', 29, Decimal('698.25226')),
#  ('MID AND SOUTH ESSEX STP', 29, Decimal('446.71970')),
#  ('STAFFORDSHIRE & STOKE ON TRENT STP', 29, Decimal('362.24984')),
#  ('MID AND SOUTH ESSEX STP', 29, Decimal('617.36063')),
#  ('MID AND SOUTH ESSEX STP', 29, Decimal('381.58344')),
#  ('MID AND SOUTH ESSEX STP', 28, Decimal('3112.06633')),
#  ('STAFFORDSHIRE & STOKE ON TRENT STP', 28, Decimal('480.54926')),
#  ('MID AND SOUTH ESSEX STP', 28, Decimal('1149.49766')),
#  ('MID AND SOUTH ESSEX STP', 28, Decimal('167.97290')),
#  ('MID AND SOUTH ESSEX STP', 28, Decimal('420.98129')),
#  ('MID AND SOUTH ESSEX STP', 28, Decimal('4792.50653')),
#  ('MID AND SOUTH ESSEX STP', 28, Decimal('3263.18444')),
#  ('MID AND SOUTH ESSEX STP', 28, Decimal('100.02700')),
#  ('MID AND SOUTH ESSEX STP', 28, Decimal('256.79963')),
#  ('MID AND SOUTH ESSEX STP', 28, Decimal('315.68131')),
#  ('MID AND SOUTH ESSEX STP', 28, Decimal('305.18480')),
#  ('NHS CHESHIRE AND MERSEYSIDE INTEGRATED C', 28, Decimal('544.43067')),
#  ('OUR HEALTHIER SOUTH EAST LONDON STP', 28, Decimal('897.94657')),
#  ('STAFFORDSHIRE & STOKE ON TRENT STP', 28, Decimal('144.49218')),
#  ('MID AND SOUTH ESSEX STP', 28, Decimal('10665.85164')),
#  ('MID AND SOUTH ESSEX STP', 28, Decimal('549.83130')),
#  ('MID AND SOUTH ESSEX STP', 28, Decimal('165.92201')),
#  ('MID AND SOUTH ESSEX STP', 28, Decimal('585.72722')),
#  ('SOUTH YORKSHIRE & BASSETLAW STP', 28, Decimal('535.47783')),
#  ('SOUTH YORKSHIRE & BASSETLAW STP', 28, Decimal('242.21165')),
#  ('CUMBRIA & NORTH EAST STP', 28, Decimal('78.50779')),
#  ('HUMBER, COAST & VALE STP', 28, Decimal('1553.87095')),
#  ('HUMBER, COAST & VALE STP', 28, Decimal('749.25327')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 28, Decimal('475.85873')),
#  ('CHESHIRE & MERSEYSIDE STP', 28, Decimal('1393.82250')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 28, Decimal('347.74768')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 28, Decimal('341.28414')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 28, Decimal('251.57689')),
#  ('HUMBER, COAST & VALE STP', 28, Decimal('144.67732')),
#  ('CHESHIRE & MERSEYSIDE STP', 28, Decimal('414.76329')),
#  ('HUMBER, COAST & VALE STP', 28, Decimal('775.37570')),
#  ('DEVON STP', 28, Decimal('1751.40238')),
#  ('HUMBER, COAST & VALE STP', 28, Decimal('265.86849')),
#  ('HUMBER, COAST & VALE STP', 28, Decimal('1303.49823')),
#  ('HUMBER, COAST & VALE STP', 28, Decimal('93.52468')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 28, Decimal('5242.54109')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 28, Decimal('199.34902')),
#  ('CHESHIRE & MERSEYSIDE STP', 28, Decimal('649.17514')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 28, Decimal('147.76952')),
#  ('HUMBER, COAST & VALE STP', 28, Decimal('125.09446')),
#  ('CHESHIRE & MERSEYSIDE STP', 28, Decimal('5958.96857')),
#  ('CHESHIRE & MERSEYSIDE STP', 28, Decimal('321.40989')),
#  ('HUMBER, COAST & VALE STP', 28, Decimal('323.65964')),
#  ('HUMBER, COAST & VALE STP', 28, Decimal('443.95278')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 28, Decimal('2121.71627')),
#  ('CHESHIRE & MERSEYSIDE STP', 28, Decimal('319.97101')),
#  ('EAST LONDON HEALTH & CARE P/SHIP STP', 28, Decimal('650.99775')),
#  ('HUMBER, COAST & VALE STP', 28, Decimal('319.34410')),
#  ('HUMBER, COAST & VALE STP', 28, Decimal('1096.28949')),
#  ('HUMBER, COAST & VALE STP', 28, Decimal('406.06172')),
#  ('CHESHIRE & MERSEYSIDE STP', 28, Decimal('207.91969')),
#  ('HUMBER, COAST & VALE STP', 28, Decimal('265.76297')),
#  ('HUMBER, COAST & VALE STP', 28, Decimal('543.98268')),
#  ('HUMBER, COAST & VALE STP', 28, Decimal('417.31847')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 28, Decimal('139.27152')),
#  ('CHESHIRE & MERSEYSIDE STP', 28, Decimal('178.60507')),
#  ('HUMBER, COAST & VALE STP', 28, Decimal('5364.50539')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 28, Decimal('188.14762')),
#  ('HUMBER, COAST & VALE STP', 28, Decimal('213.43823')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 28, Decimal('1254.25308')),
#  ('HUMBER, COAST & VALE STP', 28, Decimal('263.05961')),
#  ('CHESHIRE & MERSEYSIDE STP', 28, Decimal('1528.41021')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 28, Decimal('339.39560')),
#  ('CUMBRIA & NORTH EAST STP', 28, Decimal('352.51186')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 28, Decimal('498.02971')),
#  ('HUMBER, COAST & VALE STP', 28, Decimal('83.89326')),
#  ('HUMBER, COAST & VALE STP', 28, Decimal('208.49845')),
#  ('CHESHIRE & MERSEYSIDE STP', 28, Decimal('597.56264')),
#  ('HUMBER, COAST & VALE STP', 28, Decimal('215.89964')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 27, Decimal('983.86595')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 27, Decimal('224.58537')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 27, Decimal('225.18217')),
#  ('HUMBER, COAST & VALE STP', 27, Decimal('325.34989')),
#  ('CUMBRIA & NORTH EAST STP', 27, Decimal('465.65801')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 27, Decimal('486.79083')),
#  ('HAMPSHIRE & THE ISLE OF WIGHT STP', 27, Decimal('334.64802')),
#  ('CHESHIRE & MERSEYSIDE STP', 27, Decimal('823.16433')),
#  ('CHESHIRE & MERSEYSIDE STP', 27, Decimal('213.57644')),
#  ('CHESHIRE & MERSEYSIDE STP', 27, Decimal('605.62056')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 27, Decimal('79.45490')),
#  ('CHESHIRE & MERSEYSIDE STP', 27, Decimal('307.62851')),
#  ('HUMBER, COAST & VALE STP', 27, Decimal('3591.54006')),
#  ('CHESHIRE & MERSEYSIDE STP', 27, Decimal('282.80718')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 27, Decimal('927.43854')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 27, Decimal('295.99717')),
#  ('HUMBER, COAST & VALE STP', 27, Decimal('5063.40070')),
#  ('HUMBER, COAST & VALE STP', 27, Decimal('31879.67502')),
#  ('HUMBER, COAST & VALE STP', 27, Decimal('917.90033')),
#  ('HUMBER, COAST & VALE STP', 27, Decimal('162.21352')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 27, Decimal('593.44576')),
#  ('HUMBER, COAST & VALE STP', 27, Decimal('204.58160')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 27, Decimal('178.82097')),
#  ('CHESHIRE & MERSEYSIDE STP', 27, Decimal('925.04801')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 27, Decimal('243.33151')),
#  ('CHESHIRE & MERSEYSIDE STP', 27, Decimal('1140.73773')),
#  ('CHESHIRE & MERSEYSIDE STP', 27, Decimal('1233.71237')),
#  ('HUMBER, COAST & VALE STP', 27, Decimal('258.92473')),
#  ('HUMBER, COAST & VALE STP', 27, Decimal('10074.45229')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 27, Decimal('168.37716')),
#  ('HUMBER, COAST & VALE STP', 27, Decimal('5974.20821')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 27, Decimal('193.07139')),
#  ('HUMBER, COAST & VALE STP', 27, Decimal('427.34776')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 27, Decimal('533.76169')),
#  ('HUMBER, COAST & VALE STP', 27, Decimal('2420.91361')),
#  ('GREATER MANCHESTER HSC PARTNERSHIP STP', 27, Decimal('1579.46560')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 27, Decimal('356.98265')),
#  ('CHESHIRE & MERSEYSIDE STP', 27, Decimal('646.71909')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 27, Decimal('521.94174')),
#  ('HUMBER, COAST & VALE STP', 27, Decimal('227.74404')),
#  ('CHESHIRE & MERSEYSIDE STP', 27, Decimal('659.70387')),
#  ('HUMBER, COAST & VALE STP', 27, Decimal('378.55491')),
#  ('HUMBER, COAST & VALE STP', 27, Decimal('528.55193')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 27, Decimal('342.06133')),
#  ('CUMBRIA & NORTH EAST STP', 27, Decimal('349.03334')),
#  ('HUMBER, COAST & VALE STP', 27, Decimal('202.23932')),
#  ('HAMPSHIRE & THE ISLE OF WIGHT STP', 27, Decimal('511.64217')),
#  ('HEALTHIER LANCASHIRE & SOUTH CUMBRIA STP', 27, Decimal('501.23852')),
#  ('HUMBER, COAST & VALE STP', 27, Decimal('310.67011')),
#  ('HUMBER, COAST & VALE STP', 27, Decimal('2155.53906')),
#  ('HAMPSHIRE & THE ISLE OF WIGHT STP', 27, Decimal('1262.12577')),
#  ('HUMBER, COAST & VALE STP', 27, Decimal('3204.61442')),
#  ('MID AND SOUTH ESSEX STP', 27, Decimal('182.08816')),
#  ('MID AND SOUTH ESSEX STP', 27, Decimal('223.69231')),
#  ('MID AND SOUTH ESSEX STP', 27, Decimal('197.05920')),
#  ('MID AND SOUTH ESSEX STP', 27, Decimal('113.92480')),
#  ('MID AND SOUTH ESSEX STP', 27, Decimal('662.22695')),
#  ('MID AND SOUTH ESSEX STP', 27, Decimal('1077.74889')),
#  ('MID AND SOUTH ESSEX STP', 27, Decimal('2247.67859')),
#  ('MID AND SOUTH ESSEX STP', 27, Decimal('288.60410')),
#  ('MID AND SOUTH ESSEX STP', 27, Decimal('196.91940')),
#  ('MID AND SOUTH ESSEX STP', 27, Decimal('7946.56920')),
#  ('MID AND SOUTH ESSEX STP', 27, Decimal('2205.69612')),
#  ('MID AND SOUTH ESSEX STP', 27, Decimal('539.67394')),
#  ('NHS HUMBER AND NORTH YORKSHIRE INTEGRATE', 27, Decimal('113.27724')),
#  ('MID AND SOUTH ESSEX STP', 27, Decimal('678.48120')),
#  ('MID AND SOUTH ESSEX STP', 27, Decimal('1087.96175')),
#  ('MID AND SOUTH ESSEX STP', 27, Decimal('630.87343')),
#  ('MID AND SOUTH ESSEX STP', 27, Decimal('107.19238')),
#  ('MID AND SOUTH ESSEX STP', 27, Decimal('1125.43487')),
#  ('MID AND SOUTH ESSEX STP', 27, Decimal('183.22804')),
#  ('NHS MID AND SOUTH ESSEX INTEGRATED CARE ', 27, Decimal('299.56918')),
#  ('MID AND SOUTH ESSEX STP', 26, Decimal('1935.18786')),
#  ('STAFFORDSHIRE & STOKE ON TRENT STP', 26, Decimal('387.17250')),
#  ('SOUTH YORKSHIRE & BASSETLAW STP', 26, Decimal('306.61376')),
#  ('SOUTH YORKSHIRE & BASSETLAW STP', 26, Decimal('548.87921')),
#  ('MID AND SOUTH ESSEX STP', 26, Decimal('214.11783')),
#  ('MID AND SOUTH ESSEX STP', 26, Decimal('537.48791')),
#  ('MID AND SOUTH ESSEX STP', 26, Decimal('277.45452')),
#  ('MID AND SOUTH ESSEX STP', 26, Decimal('2123.43600')),
#  ('MID AND SOUTH ESSEX STP', 26, Decimal('897.86957')),
#  ('MID AND SOUTH ESSEX STP', 26, Decimal('758.08457')),
#  ('MID AND SOUTH ESSEX STP', 26, Decimal('6806.98512')),
#  ('NHS HUMBER AND NORTH YORKSHIRE INTEGRATE', 26, Decimal('272.00379')),
#  ('MID AND SOUTH ESSEX STP', 26, Decimal('2029.76846')),
#  ('MID AND SOUTH ESSEX STP', 26, Decimal('2588.37202')),
#  ('MID AND SOUTH ESSEX STP', 26, Decimal('7551.38218')),
#  ('STAFFORDSHIRE & STOKE ON TRENT STP', 26, Decimal('929.87747')),
#  ('MID AND SOUTH ESSEX STP', 26, Decimal('940.36413')),
#  ('MID AND SOUTH ESSEX STP', 26, Decimal('196.05395')),
#  ('SOUTH YORKSHIRE & BASSETLAW STP', 26, Decimal('325.43801')),
#  ('STAFFORDSHIRE & STOKE ON TRENT STP', 26, Decimal('157.65747')),
#  ('MID AND SOUTH ESSEX STP', 26, Decimal('363.27445')),
#  ('MID AND SOUTH ESSEX STP', 26, Decimal('140.33083')),
#  ('NHS GREATER MANCHESTER INTEGRATED CARE B', 26, Decimal('243.92974')),
#  ('MID AND SOUTH ESSEX STP', 26, Decimal('550.43904')),
#  ('NHS NORTH EAST LONDON INTEGRATED CARE BO', 26, Decimal('871.22506')),
#  ('MID AND SOUTH ESSEX STP', 26, Decimal('593.09378')),
#  ('STAFFORDSHIRE & STOKE ON TRENT STP', 26, Decimal('639.99869')),
#  ('STAFFORDSHIRE & STOKE ON TRENT STP', 26, Decimal('380.49683')),
#  ('STAFFORDSHIRE & STOKE ON TRENT STP', 26, Decimal('196.14552')),
#  ('STAFFORDSHIRE & STOKE ON TRENT STP', 26, Decimal('188.74276')),
#  ('MID AND SOUTH ESSEX STP', 26, Decimal('305.90337')),
#  ('MID AND SOUTH ESSEX STP', 26, Decimal('405.33923')),
#  ('MID AND SOUTH ESSEX STP', 26, Decimal('112.05714')),
#  ...]
