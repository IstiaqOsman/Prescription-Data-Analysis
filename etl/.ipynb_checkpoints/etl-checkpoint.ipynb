# %%
import pandas as pd
data = pd.read_csv(r"G:\HDA5\Presciption Data Analysis\data123.csv")

# %%
data.columns
# Out:
# Index(['YEAR_MONTH', 'YEAR', 'MONTH', 'REGIONAL_OFFICE_NAME',
#        'REGIONAL_OFFICE_CODE', 'STP_NAME', 'STP_CODE', 'PCO_NAME', 'PCO_CODE',
#        'PRACTICE_NAME', 'PRACTICE_CODE', 'ADDRESS_1', 'ADDRESS_2', 'ADDRESS_3',
#        'ADDRESS_4', 'POSTCODE', 'BNF_CHEMICAL_SUBSTANCE',
#        'CHEMICAL_SUBSTANCE_BNF_DESCR', 'BNF_CODE', 'BNF_DESCRIPTION',
#        'BNF_CHAPTER_PLUS_CODE', 'QUANTITY', 'ITEMS', 'TOTAL_QUANTITY',
#        'ADQUSAGE', 'NIC', 'ACTUAL_COST', 'UNIDENTIFIED', 'SNOMED_CODE'],
#       dtype='object')

# %%
data.shape
# Out:
# (209982, 29)

# %%
data = data.drop_duplicates(['YEAR_MONTH', 'YEAR', 'MONTH', 'REGIONAL_OFFICE_NAME',
       'REGIONAL_OFFICE_CODE', 'STP_NAME', 'STP_CODE', 'PCO_NAME', 'PCO_CODE',
       'PRACTICE_NAME', 'PRACTICE_CODE', 'ADDRESS_1', 'ADDRESS_2', 'ADDRESS_3',
       'ADDRESS_4', 'POSTCODE', 'BNF_CHEMICAL_SUBSTANCE',
       'CHEMICAL_SUBSTANCE_BNF_DESCR', 'BNF_CODE', 'BNF_DESCRIPTION',
       'BNF_CHAPTER_PLUS_CODE', 'QUANTITY', 'ITEMS', 'TOTAL_QUANTITY',
       'ADQUSAGE', 'NIC', 'ACTUAL_COST', 'UNIDENTIFIED', 'SNOMED_CODE'])

# %%
LOCATION_KEY = []
for i in range(0,len(data)):
    LOCATION_KEY.append(str('L0' + data._get_value(i, 'REGIONAL_OFFICE_CODE') + data._get_value(i, 'STP_CODE') + 
                            data._get_value(i, 'PCO_CODE'))+ data._get_value(i, 'POSTCODE'))
    
#     str('L0' + data._get_value(1, 'REGIONAL_OFFICE_CODE')[0] + data._get_value(1, 'STP_CODE')[0] + 
#     data._get_value(1, 'PCO_CODE')[0] + data._get_value(0, 'POSTCODE')[0:3])
#     LOCATION_KEY.append('L0' + str(dataDump_df._get_value(i, 'REGIONAL_OFFICE_CODE')[0]) + 
#     str(dataDump_df._get_value(i, 'STP_CODE')[0]) + str(dataDump_df._get_value(i, 'PCO_CODE')[0]) + 
#     str(dataDump_df._get_value(i, 'POSTCODE')[0:3]))

data['LOCATION_KEY'] = pd.Series(LOCATION_KEY, index=data.index)
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File G:\HDA5\myenv\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File G:\HDA5\myenv\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File G:\HDA5\myenv\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 9536
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
data['YEAR_MONTH'] = data['YEAR_MONTH'].astype(str)

# %%
uniqueValues = data.nunique()
print(uniqueValues)
# Out:
# YEAR_MONTH                          21
# YEAR                                 3
# MONTH                               12
# REGIONAL_OFFICE_NAME                 8
# REGIONAL_OFFICE_CODE                 8
# STP_NAME                            72
# STP_CODE                            40
# PCO_NAME                           301
# PCO_CODE                           225
# PRACTICE_NAME                     1413
# PRACTICE_CODE                     1430
# ADDRESS_1                         1226
# ADDRESS_2                         1093
# ADDRESS_3                          519
# ADDRESS_4                          160
# POSTCODE                          1128
# BNF_CHEMICAL_SUBSTANCE            1174
# CHEMICAL_SUBSTANCE_BNF_DESCR      1072
# BNF_CODE                          8967
# BNF_DESCRIPTION                   8975
# BNF_CHAPTER_PLUS_CODE               20
# QUANTITY                           684
# ITEMS                              405
# TOTAL_QUANTITY                    1610
# ...

# %%
a = pd.unique(data[['ADDRESS_1']].values.ravel())

# %%
print(list(a))
# Out:
# ["ST.LAURENCE'S MEDICAL CTR", 'STOCKTON HEATH MED.CENTRE', 'GRANTHAM HOSPITAL', 'THE SURGERY, BOYDEN CLOSE', 'THE CIRCLE PRACTICE', 'THE ESPLANADE SURGERY', 'WESTON LANE CTR HLTHY LVG', 'MEDINA HEALTHCARE', 'CLAYTON BROOK SURGERY', 'COPPULL MEDICAL PRACTICE', 'THE NEW DISPENSARY', 'FULLWELL CROSS MED. CTR', 'DINNINGTON GROUP PRACTICE', 'FELTHAM CENTRE', 'BLUNDELLSANDS SURGERY', '22 CARISBROOKE HIGH ST', 'THE SURGERY', 'VICTORIA MEDICAL CENTRE', 'LAPWORTH SURGERY', 'GREASBROUGH MEDICAL CTR', 'TYNEHEALTH', 'OLD GATCOMBE WARD', "ST MARY'S HOSPITAL", 'WESTGATE HSE, HILLSIDE HC', 'CORUM ONE, OFFICE PARK', 'WITHYWOOD CENTRE', 'TICKHILL ROAD SITE', 'WEAVER VALE PRACTICE', 'WINGATE MEDICAL CENTRE', '291 ASHBY ROAD', 'CLEETHORPES PCC', 'THE MEDICAL CENTRE', 'ST WULFSTAN SURGERY', 'MEDICAL CENTRE', 'THE HEALTH CENTRE UNIT F1', 'CHAPELFORD MEDICAL CENTRE', 'WILLIAM BUDD HEALTH CTR', '2ND FLOOR, CASTLEWOOD', 'SOUTH TYNESIDE HOSPITAL', 'ST.HELENS MEDICAL CENTRE', 'SUNNYSIDE MEDICAL CENTRE', 'BROA
# ...

# %%
PRESCRIPTION_KEY = []
for i in range(0,len(data)):
    PRESCRIPTION_KEY.append(str('P0' + data._get_value(i, 'REGIONAL_OFFICE_CODE') + data._get_value(i, 'STP_CODE') + 
                            data._get_value(i, 'PCO_CODE'))+ data._get_value(i, 'POSTCODE'))
    data['LOCATION_KEY'] = pd.Series(LOCATION_KEY, index=data.index)
data

# %%
data.columns
# Out:
# Index(['YEAR_MONTH', 'YEAR', 'MONTH', 'REGIONAL_OFFICE_NAME',
#        'REGIONAL_OFFICE_CODE', 'STP_NAME', 'STP_CODE', 'PCO_NAME', 'PCO_CODE',
#        'PRACTICE_NAME', 'PRACTICE_CODE', 'ADDRESS_1', 'ADDRESS_2', 'ADDRESS_3',
#        'ADDRESS_4', 'POSTCODE', 'BNF_CHEMICAL_SUBSTANCE',
#        'CHEMICAL_SUBSTANCE_BNF_DESCR', 'BNF_CODE', 'BNF_DESCRIPTION',
#        'BNF_CHAPTER_PLUS_CODE', 'QUANTITY', 'ITEMS', 'TOTAL_QUANTITY',
#        'ADQUSAGE', 'NIC', 'ACTUAL_COST', 'UNIDENTIFIED', 'SNOMED_CODE'],
#       dtype='object')

# %%
data.head()
# Out:
#    YEAR_MONTH  YEAR  MONTH REGIONAL_OFFICE_NAME REGIONAL_OFFICE_CODE  \
# 0      202011  2020     11           NORTH WEST                  Y62
# 1      202011  2020     11           NORTH WEST                  Y62
# 2      202011  2020     11           NORTH WEST                  Y62
# 3      202011  2020     11           NORTH WEST                  Y62
# 4      202011  2020     11           NORTH WEST                  Y62
#
#                     STP_NAME STP_CODE        PCO_NAME  PCO_CODE  \
# 0  CHESHIRE & MERSEYSIDE STP      QYG    KNOWSLEY CCG     01J00
# 1  CHESHIRE & MERSEYSIDE STP      QYG    KNOWSLEY CCG     01J00
# 2  CHESHIRE & MERSEYSIDE STP      QYG    KNOWSLEY CCG     01J00
# 3  CHESHIRE & MERSEYSIDE STP      QYG  WARRINGTON CCG  2.00E+00
# 4  CHESHIRE & MERSEYSIDE STP      QYG  WARRINGTON CCG  2.00E+00
#
#                    PRACTICE_NAME  ...  \
# 0  ST. LAURENCE'S MEDICAL CENTRE  ...
# 1  ST. LAURENCE'S MEDICAL CENTRE  ...
# 2  ST. LAURENCE'S MEDICAL CENTRE  ...
# ...

# %%
Location = data.drop(['YEAR_MONTH', 'YEAR', 'MONTH', 'PRACTICE_NAME', 'PRACTICE_CODE','BNF_CHEMICAL_SUBSTANCE',
       'CHEMICAL_SUBSTANCE_BNF_DESCR', 'BNF_CODE', 'BNF_DESCRIPTION',
       'BNF_CHAPTER_PLUS_CODE', 'QUANTITY', 'ITEMS', 'TOTAL_QUANTITY',
       'ADQUSAGE', 'NIC', 'ACTUAL_COST', 'UNIDENTIFIED', 'SNOMED_CODE'],axis=1)

# %%
Location.shape
# Out:
# (1934, 11)

# %%
print(Location.nunique())
# Out:
# REGIONAL_OFFICE_NAME       8
# REGIONAL_OFFICE_CODE       8
# STP_NAME                  72
# STP_CODE                  40
# PCO_NAME                 301
# PCO_CODE                 225
# ADDRESS_1               1226
# ADDRESS_2               1093
# ADDRESS_3                519
# ADDRESS_4                160
# POSTCODE                1129
# dtype: int64

# %%
Location = Location.drop_duplicates(['REGIONAL_OFFICE_NAME', 'REGIONAL_OFFICE_CODE', 'STP_NAME', 'STP_CODE',
       'PCO_NAME', 'PCO_CODE', 'ADDRESS_1', 'ADDRESS_2', 'ADDRESS_3',
       'ADDRESS_4', 'POSTCODE'])

# %%
LOCATION_KEY = []
for i in range(0,len(Location)):
    LOCATION_KEY.append(str('L0' + Location._get_value(i, 'REGIONAL_OFFICE_CODE') + Location._get_value(i, 'STP_CODE') + 
                            Location._get_value(i, 'PCO_CODE'))+ Location._get_value(i, 'POSTCODE'))
Location['LOCATION_KEY'] = pd.Series(LOCATION_KEY, index=Location.index)
Location
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File G:\HDA5\myenv\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File G:\HDA5\myenv\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File G:\HDA5\myenv\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
LOCATION_KEY = []
for i in range(0,len(data)):
    if(i<10):
        LOCATION_KEY.append('L00000'+str(i))
    elif(10<=i and i<100):
       LOCATION_KEY.append('L0000'+str(i))
    elif(100<=i and i<1000):
       LOCATION_KEY.append('L000'+str(i))
    elif(1000<=i and i<10000):
       LOCATION_KEY.append('L00'+str(i))
    elif(10000<=i and i<100000):
       LOCATION_KEY.append('L0'+str(i))
    else:
       LOCATION_KEY.append('L'+str(i))
data['LOCATION_KEY'] = pd.Series(LOCATION_KEY, index=data.index)
data
# Out:
#         YEAR_MONTH  YEAR  MONTH REGIONAL_OFFICE_NAME REGIONAL_OFFICE_CODE  \
# 0           202011  2020     11           NORTH WEST                  Y62
# 1           202011  2020     11           NORTH WEST                  Y62
# 2           202011  2020     11           NORTH WEST                  Y62
# 3           202011  2020     11           NORTH WEST                  Y62
# 4           202011  2020     11           NORTH WEST                  Y62
# ...            ...   ...    ...                  ...                  ...
# 209988      202207  2022      7           NORTH WEST                  Y62
# 209989      202207  2022      7           NORTH WEST                  Y62
# 209990      202207  2022      7           NORTH WEST                  Y62
# 209991      202207  2022      7           NORTH WEST                  Y62
# 209992      202207  2022      7           NORTH WEST                  Y62
#
#                                         STP_NAME STP_CODE  \
# ...

# %%
PRESCRIPTION_KEY = []
for i in range(0,len(data)):
    if(i<10):
        PRESCRIPTION_KEY.append('P00000'+str(i))
    elif(10<=i and i<100):
       PRESCRIPTION_KEY.append('P0000'+str(i))
    elif(100<=i and i<1000):
       PRESCRIPTION_KEY.append('P000'+str(i))
    elif(1000<=i and i<10000):
       PRESCRIPTION_KEY.append('P00'+str(i))
    elif(10000<=i and i<100000):
       PRESCRIPTION_KEY.append('P0'+str(i))
    else:
       PRESCRIPTION_KEY.append('P'+str(i))
data['PRESCRIPTION_KEY'] = pd.Series(PRESCRIPTION_KEY, index=data.index)
data
# Out:
#         YEAR_MONTH  YEAR  MONTH REGIONAL_OFFICE_NAME REGIONAL_OFFICE_CODE  \
# 0           202011  2020     11           NORTH WEST                  Y62
# 1           202011  2020     11           NORTH WEST                  Y62
# 2           202011  2020     11           NORTH WEST                  Y62
# 3           202011  2020     11           NORTH WEST                  Y62
# 4           202011  2020     11           NORTH WEST                  Y62
# ...            ...   ...    ...                  ...                  ...
# 209988      202207  2022      7           NORTH WEST                  Y62
# 209989      202207  2022      7           NORTH WEST                  Y62
# 209990      202207  2022      7           NORTH WEST                  Y62
# 209991      202207  2022      7           NORTH WEST                  Y62
# 209992      202207  2022      7           NORTH WEST                  Y62
#
#                                         STP_NAME STP_CODE  \
# ...

# %%
TIME_KEY = []
data['TIME_KEY'] = 'T'+ data['YEAR_MONTH']
data
# Out:
#        YEAR_MONTH  YEAR MONTH REGIONAL_OFFICE_NAME REGIONAL_OFFICE_CODE  \
# 0          202011  2020    11           NORTH WEST                  Y62
# 1          202011  2020    11           NORTH WEST                  Y62
# 2          202011  2020    11           NORTH WEST                  Y62
# 3          202011  2020    11           NORTH WEST                  Y62
# 4          202011  2020    11           NORTH WEST                  Y62
# ...           ...   ...   ...                  ...                  ...
# 209988     202207  2022     7           NORTH WEST                  Y62
# 209989     202207  2022     7           NORTH WEST                  Y62
# 209990     202207  2022     7           NORTH WEST                  Y62
# 209991     202207  2022     7           NORTH WEST                  Y62
# 209992     202207  2022     7           NORTH WEST                  Y62
#
#                                         STP_NAME STP_CODE  \
# ...

# %%
location.columns

# %%
location.head()

# %%
LOCATION_KEY = []
for i in range(0,len(data)):
    LOCATION_KEY.append(str('L0' + data._get_value(i, 'REGIONAL_OFFICE_CODE') + data._get_value(i, 'STP_CODE') + 
                            data._get_value(i, 'PCO_CODE'))+ data._get_value(i, 'POSTCODE'))
    
    
#     str('L0' + data._get_value(1, 'REGIONAL_OFFICE_CODE')[0] + data._get_value(1, 'STP_CODE')[0] + 
#     data._get_value(1, 'PCO_CODE')[0] + data._get_value(0, 'POSTCODE')[0:3])
#     LOCATION_KEY.append('L0' + str(dataDump_df._get_value(i, 'REGIONAL_OFFICE_CODE')[0]) + 
#     str(dataDump_df._get_value(i, 'STP_CODE')[0]) + str(dataDump_df._get_value(i, 'PCO_CODE')[0]) + 
#     str(dataDump_df._get_value(i, 'POSTCODE')[0:3]))

data['LOCATION_KEY'] = pd.Series(LOCATION_KEY, index=data.index)
data

# %%
location = data.drop(['YEAR_MONTH', 'YEAR', 'MONTH', 
       'PRACTICE_NAME', 'PRACTICE_CODE', 'BNF_CHEMICAL_SUBSTANCE',
       'CHEMICAL_SUBSTANCE_BNF_DESCR', 'BNF_CODE', 'BNF_DESCRIPTION',
       'BNF_CHAPTER_PLUS_CODE', 'QUANTITY', 'ITEMS', 'TOTAL_QUANTITY',
       'ADQUSAGE', 'NIC', 'ACTUAL_COST', 'UNIDENTIFIED', 'SNOMED_CODE',
       'PRESCRIPTION_KEY', 'TIME_KEY'],axis=1)

# %%
service.reset_index(drop=True, inplace=True)

# %%
con = PostgresConnection().getConnection()
insert_stmt = "INSERT INTO snow.prescription(BNF_CHEMICAL_SUBSTANCE, BNF_CODE, BNF_DESCRIPTION,BNF_CHAPTER_PLUS_CODE, QUANTITY, ADQUSAGE, NIC, SNOMED_CODE,PRESCRIPTION_KEY) VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)"
cur = con.cursor()
psycopg2.extras.execute_batch(cur, insert_stmt, prescription.values)
con.commit()
cur.close()
# Out:
# Index(['REGIONAL_OFFICE_NAME', 'REGIONAL_OFFICE_CODE', 'STP_NAME', 'STP_CODE',
#        'PCO_NAME', 'PCO_CODE', 'ADDRESS_1', 'ADDRESS_2', 'ADDRESS_3',
#        'ADDRESS_4', 'POSTCODE', 'LOCATION_KEY'],
#       dtype='object')

# %%
service.shape
# Out:
# (1430, 2)

# %%
service = data.drop(['YEAR_MONTH', 'YEAR', 'MONTH', 'REGIONAL_OFFICE_NAME',
       'REGIONAL_OFFICE_CODE', 'STP_NAME', 'STP_CODE', 'PCO_NAME', 'PCO_CODE',
        'ADDRESS_1', 'ADDRESS_2', 'ADDRESS_3',
       'ADDRESS_4', 'POSTCODE', 'BNF_CHEMICAL_SUBSTANCE',
       'CHEMICAL_SUBSTANCE_BNF_DESCR', 'BNF_CODE', 'BNF_DESCRIPTION',
       'BNF_CHAPTER_PLUS_CODE', 'QUANTITY', 'ITEMS', 'TOTAL_QUANTITY',
       'ADQUSAGE', 'NIC', 'ACTUAL_COST', 'UNIDENTIFIED', 'SNOMED_CODE',
       'LOCATION_KEY', 'PRESCRIPTION_KEY', 'TIME_KEY'],axis=1)

# %% [markdown]
# service.reset_index(drop=True, inplace=True)

# %%
service.head()
# Out:
#                    PRACTICE_NAME PRACTICE_CODE
# 0  ST. LAURENCE'S MEDICAL CENTRE        N83033
# 1      STOCKTON HEATH MED.CENTRE        N81075
# 2    URGENT TREATMENT CENTRE OOH        Y00753
# 3           WICKHAMBROOK SURGERY        D83003
# 4            THE CIRCLE PRACTICE        E84004

# %%
service = service.drop_duplicates(['PRACTICE_CODE'])

# %%
prescription = data.drop(['YEAR_MONTH', 'YEAR', 'MONTH', 'REGIONAL_OFFICE_NAME',
       'REGIONAL_OFFICE_CODE', 'STP_NAME', 'STP_CODE', 'PCO_NAME', 'PCO_CODE',
       'PRACTICE_NAME', 'PRACTICE_CODE', 'ADDRESS_1', 'ADDRESS_2', 'ADDRESS_3',
       'ADDRESS_4', 'POSTCODE', 'CHEMICAL_SUBSTANCE_BNF_DESCR', 'ITEMS', 'TOTAL_QUANTITY',
     'ACTUAL_COST', 'UNIDENTIFIED',
       'LOCATION_KEY', 'TIME_KEY'],axis=1)

# %%
prescription.columns
# Out:
# Index(['BNF_CHEMICAL_SUBSTANCE', 'BNF_CODE', 'BNF_DESCRIPTION',
#        'BNF_CHAPTER_PLUS_CODE', 'QUANTITY', 'ADQUSAGE', 'NIC', 'SNOMED_CODE',
#        'PRESCRIPTION_KEY'],
#       dtype='object')

# %%
data.reset_index(drop=True, inplace=True)

# %%
prescription.head()
# Out:
#   BNF_CHEMICAL_SUBSTANCE         BNF_CODE  \
# 0              0212000AA  0212000AAAAADAD
# 1              0407010N0  0407010N0BGABAI
# 2               1.00E+06  1001010E0AAADAD
# 3              0105010B0  0105010B0BIABAA
# 4              0206010K0  0206010K0BNACAE
#
#                             BNF_DESCRIPTION  \
# 0                  Rosuvastatin 5mg tablets
# 1                   Remedeine Forte tablets
# 2   Etodolac 600mg modified-release tablets
# 3  Octasa 400mg MR gastro-resistant tablets
# 4                         Isib 60XL tablets
#
#                     BNF_CHAPTER_PLUS_CODE  QUANTITY  ADQUSAGE     NIC  \
# 0               02: Cardiovascular System      28.0      14.0    1.52
# 1              04: Central Nervous System     200.0     700.0  341.04
# 2  10: Musculoskeletal and Joint Diseases      28.0      28.0   14.47
# 3            01: Gastro-Intestinal System     168.0      42.0   30.94
# 4               02: Cardiovascular System      14.0       0.0    4.08
#
# ...

# %%
prescription.shape
# Out:
# (209982, 9)

# %%
bnf_chemical = data.drop(['YEAR_MONTH', 'YEAR', 'MONTH', 'REGIONAL_OFFICE_NAME',
       'REGIONAL_OFFICE_CODE', 'STP_NAME', 'STP_CODE', 'PCO_NAME', 'PCO_CODE',
       'PRACTICE_NAME', 'PRACTICE_CODE', 'ADDRESS_1', 'ADDRESS_2', 'ADDRESS_3',
       'ADDRESS_4', 'POSTCODE', 'BNF_CODE', 'BNF_DESCRIPTION',
       'BNF_CHAPTER_PLUS_CODE', 'QUANTITY', 'ITEMS', 'TOTAL_QUANTITY',
       'ADQUSAGE', 'NIC', 'ACTUAL_COST', 'UNIDENTIFIED', 'SNOMED_CODE',
       'LOCATION_KEY', 'PRESCRIPTION_KEY', 'TIME_KEY'],axis=1)

# %%
bnf_chemical.shape
# Out:
# (1174, 2)

# %%
bnf_chemical.head()
# Out:
#   BNF_CHEMICAL_SUBSTANCE              CHEMICAL_SUBSTANCE_BNF_DESCR
# 0              0212000AA                      Rosuvastatin calcium
# 1              0407010N0  Co-dydramol (Dihydrocodeine/paracetamol)
# 2               1.00E+06                                  Etodolac
# 3              0105010B0                     Mesalazine (Systemic)
# 4              0206010K0                    Isosorbide mononitrate

# %%
service.reset_index(drop=True, inplace=True)

# %%
# bnf_chemical.shape
bnf_chemical = bnf_chemical.drop_duplicates(['BNF_CHEMICAL_SUBSTANCE'])

# %%
fact_table = data.drop(['YEAR_MONTH', 'YEAR', 'MONTH', 'REGIONAL_OFFICE_NAME',
       'REGIONAL_OFFICE_CODE', 'STP_NAME', 'STP_CODE', 'PCO_NAME', 'PCO_CODE',
       'PRACTICE_NAME', 'ADDRESS_1', 'ADDRESS_2', 'ADDRESS_3',
       'ADDRESS_4', 'POSTCODE', 'BNF_CHEMICAL_SUBSTANCE',
       'CHEMICAL_SUBSTANCE_BNF_DESCR', 'BNF_CODE', 'BNF_DESCRIPTION',
       'BNF_CHAPTER_PLUS_CODE',
       'ADQUSAGE', 'NIC', 'UNIDENTIFIED', 'SNOMED_CODE'],axis=1)

# %%
fact_table.shape
# Out:
# (209982, 8)

# %%
fact_table.head()
# Out:
#   PRACTICE_CODE  QUANTITY  ITEMS  TOTAL_QUANTITY  ACTUAL_COST LOCATION_KEY  \
# 0        N83033      28.0      1            28.0      1.42625      L000000
# 1        N83033     200.0     14          2800.0    318.79728      L000001
# 2        N83033      28.0      1            28.0     13.57190      L000002
# 3        N81075     168.0      1           168.0     28.89172      L000003
# 4        N81075      14.0      1            14.0      3.90748      L000004
#
#   PRESCRIPTION_KEY TIME_KEY
# 0          P000000  T202011
# 1          P000001  T202011
# 2          P000002  T202011
# 3          P000003  T202011
# 4          P000004  T202011

# %%
TIME_KEY = []
data['TIME_KEY'] = 'T'+ data['YEAR_MONTH']
data

# %%
time = data.drop(['YEAR_MONTH', 'REGIONAL_OFFICE_NAME',
       'REGIONAL_OFFICE_CODE', 'STP_NAME', 'STP_CODE', 'PCO_NAME', 'PCO_CODE',
       'PRACTICE_NAME', 'PRACTICE_CODE', 'ADDRESS_1', 'ADDRESS_2', 'ADDRESS_3',
       'ADDRESS_4', 'POSTCODE', 'BNF_CHEMICAL_SUBSTANCE',
       'CHEMICAL_SUBSTANCE_BNF_DESCR', 'BNF_CODE', 'BNF_DESCRIPTION',
       'BNF_CHAPTER_PLUS_CODE', 'QUANTITY', 'ITEMS', 'TOTAL_QUANTITY',
       'ADQUSAGE', 'NIC', 'ACTUAL_COST', 'UNIDENTIFIED', 'SNOMED_CODE',
       'LOCATION_KEY', 'PRESCRIPTION_KEY'],axis=1)

# %%
time.head()
# Out:
#    YEAR  MONTH TIME_KEY
# 0  2020     11  T202011
# 1  2020     12  T202012
# 2  2021      1  T202101
# 3  2021      2  T202102
# 4  2021      3  T202103

# %%
service.reset_index(drop=True, inplace=True)

# %%
time.shape
# time = time.drop_duplicates(['TIME_KEY', 'YEAR', 'MONTH'])
# Out:
# (21, 3)

# %%
# str('L0' + data._get_value(1, 'REGIONAL_OFFICE_CODE')[0] + data._get_value(1, 'STP_CODE')[0] + 
#     data._get_value(1, 'PCO_CODE')[0] + data._get_value(0, 'POSTCODE')[0:3])
# Out:
# 'L0YQ0L32'

# %%
time.dtypes
# Out:
# YEAR         int64
# MONTH        int64
# TIME_KEY    object
# dtype: object

# %%
bnf_chemical.values
# Out:
# array([['0212000AA', 'Rosuvastatin calcium'],
#        ['0407010N0', 'Co-dydramol (Dihydrocodeine/paracetamol)'],
#        ['1.00E+06', 'Etodolac'],
#        ...,
#        ['1203010C0', 'Benzocaine'],
#        ['0212000AM', 'Inclisiran'],
#        ['1203030A0', 'Amylmetacresol']], dtype=object)

# %%
bnf_chemical.nunique()
# Out:
# BNF_CHEMICAL_SUBSTANCE          1174
# CHEMICAL_SUBSTANCE_BNF_DESCR    1072
# dtype: int64

# %%
import psycopg2
import pandas as pd
import psycopg2.extras

# %%
class PostgresConnection(object):
    def __init__(self):
        self.connection = psycopg2.connect(database="presdb",
                                           user = "postgres",
                                           password = "",
                                           host = "127.0.0.1",
                                           port = "5432")

    def getConnection(self):
        print("Connection to DB established!")
        return self.connection
con = PostgresConnection().getConnection()
# Out:
# Connection to DB established!

# %%
con = PostgresConnection().getConnection()
insert_stmt = "INSERT INTO snow.prescription(BNF_CHEMICAL_SUBSTANCE, BNF_CODE, BNF_DESCRIPTION,BNF_CHAPTER_PLUS_CODE, QUANTITY, ADQUSAGE, NIC, SNOMED_CODE,PRESCRIPTION_KEY) VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)"
cur = con.cursor()
psycopg2.extras.execute_batch(cur, insert_stmt, prescription.values)
con.commit()
cur.close()
# Out:
# Connection to DB established!

# %%
con = PostgresConnection().getConnection()
insert_stmt = "INSERT INTO snow.service(PRACTICE_NAME,PRACTICE_CODE) VALUES (%s,%s)"
cur = con.cursor()
psycopg2.extras.execute_batch(cur, insert_stmt, service.values)
con.commit()
cur.close()
# Out:
# Connection to DB established!

# %%
fact_table.columns
# Out:
# Index(['PRACTICE_CODE', 'QUANTITY', 'ITEMS', 'TOTAL_QUANTITY', 'ACTUAL_COST',
#        'LOCATION_KEY', 'PRESCRIPTION_KEY', 'TIME_KEY'],
#       dtype='object')

# %%
con = PostgresConnection().getConnection()
insert_stmt = "INSERT INTO snow.fact_table(PRACTICE_CODE, QUANTITY, ITEMS, TOTAL_QUANTITY, ACTUAL_COST,LOCATION_KEY, PRESCRIPTION_KEY, TIME_KEY) VALUES (%s,%s,%s,%s,%s,%s,%s,%s)"
cur = con.cursor()
psycopg2.extras.execute_batch(cur, insert_stmt, fact_table.values)
con.commit()
cur.close()
# Out:
# Connection to DB established!
